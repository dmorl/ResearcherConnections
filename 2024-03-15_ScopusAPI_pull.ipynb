# %% [markdown]
# # Scopus API Pull and Research Connection Script

# %% [markdown]
# #### <b> Last Updated: 2024-04-22 </b>
# This is a script originally created in October 2019, and reconfigured in March 2024. It takes in Scopus IDs from WMU and WMed researchers and returns author keywords associated with their publications. These keywords, along with ingested keywords from ORCiD profiles, directory pages, departmental research topic websites, and FARS keywords, are then exported in as a csv aggregating researchers by a single research keyword (in the format "keyword | researcherID(s) | researchName(s) | researcherAffiliation(s)"). The overarching purpose of this project is to help make connections between researchers with similar interests for expanding interdisciplinary collaboration. The script accomplishes the following actions within each cell:
#
# * <b>In[1]</b> Imports relevant libraries.\
# <i>Note: pybliometrics is not a default python library and will need to be installed first using "pip install pybliometrics". Scopus API key will need to be acquired through the Elsevier Developer Portal at http://dev.elsevier.com/myapikey.html, which pybliometrics will prompt you to enter upon library installation to create a configuration file on your system. A InstToken is not required. To obtain the API Key, you will need to log into Scopus with your institutional affiliation. To query the API, users will need to be on campus.</i>
# For more information about pybliometrics, please see the documentation: https://pybliometrics.readthedocs.io/en/stable/
# <br></br>
# * <b>In[2]</b> Lists all the .txt and .csv files required within the script. \
# These include: a plain text (.txt) file listing all the researcher Scopus IDs, separated by commas (for querying the Scopus API, in the format: "ScopusID1,ScopusID2...etc"); a plain text file listing WMU researcher Scopus IDs (for querying the Scopus API, in the format: "ScopusID1,ScopusID2...etc"); a comma separated value (.csv) file created by the script in ln[4] that includes a full output of articles along with all the associated metadata for each researcher Scopus ID; a plain text file matching unique researcher IDs to related Scopus IDs (in the format "ID:ScopusID1; ScopusID2"); a plain text file matching unique researcher IDs to additional research keywords (in the format "ID:keywordORCiD; keywordDirectory; keywordFARS"); a plain text file making unique researcher IDs to researcher names and affiliation (in the format "ID:researcherName;Dept1 | Dept2").
# <br></br>
# * <b>In[3]</b> Creates list of ScopusIDs in a format readable by the API. \
# Opens the listing of all the researcher Scopus IDs (researcher_ScopusID_list) and reads the contents in, modifying the IDs to include the designation "Au_ID" required by ScopusSearch (in ln[4]), and splitting the IDs into items within a list, authors_ids
# <br></br>
# * <b>In[4]</b> Returns articles associated with the ScopusIDs. \
# Using the authors_ids list, all the researcher IDs are looped through the Scopus API via ScopusSearch, returning all the articles associated with each Scopus ID. These articles are added to a pandas dataframe, which holds onto the information while the next Scopus ID within the list is used to query the API. The resulting dataframe is exported ("date_researcher-articles-complete.csv"), using the date that the script was initialized
# <br></br>
# * <b>In[5]</b> Creates list of WMU ScopusIDs in a format readable by the API. \
# Opens the listing of just WMU researcher Scopus IDs (partialresearcher_ScopusID_list) and reads the contents in, modifying the IDs to include the designation "Au_ID" required by ScopusSearch, and splitting the IDs into items within a list, partial_authors_ids
# <br></br>
# * <b>In[6]</b> Returns articles associated with only WMU ScopusIDs. \
# Using the partial_authors_ids list, only the WMU researcher IDs are looped through the Scopus API via ScopusSearch, returning all the articles associated with each Scopus ID. These articles are added to a pandas dataframe, which holds onto the information while the next Scopus ID within the list is used to query the API. The resulting dataframe is exported ("date_researcher-articles-WMU.csv"), using the date that the script was initialized
# <br></br>
# * <b>In[7]</b> Uses script-generated file of all articles associated with ScopusIDs (exported in In[4]). \
# The csv with the full Scopus ID articles list ("date_researcher_articles_list.csv") is read back into the script as a dataframe outside of querying the API. The dataframe is printed as a check to see if everything is working correctly
# <br></br>
# * <b>In[8]</b> Extracts author keywords from associated ScopusIDs in file (In[7]), merging all keywords across multiple scholarship under one ScopusID. \
# A dictionary (aukey_dict) is created from the df_full_articles dataframe, where the Scopus ID (key) is associated with the author keywords (values) from all the articles associated with the Scopus ID. Since author keywords is a user-generated field, it is possible that a researcher may have many articles without any author keywords, and therefore the value for that ID key might be "nan" (none). It is also possible that a researcher might have many Scopus IDs if they haven't been merged, and will be represented more than once within this dictionary.
# <br></br>
# * <b>In[9]</b> Replaces ScopusIDs with researcherIDs, merging all ScopusIDs associated with a researcherID into a single entry. \
# A txt file associating researcher IDs with their Scopus IDs is read into the script (researcher_scopus). A dictionary, researkey_dict, is created substituting the Scopus ID with researcher IDs as the key, and adding the Scopus author keywords as the values. In the case where a researcher does not have a Scopus ID, then the researcher ID is added to the dictionary without associated values.
# <br></br>
# * <b>In[10]</b> Adds additional research keywords to single researcherID entry. \
# A txt file associating researcher IDs with additional keywords from ORCiD, directories, researcher departmental topic websites, Faculty Annual Reporting portal (FARS) is read into the script(researcher_additionalkeywords). The researkey_dict is used as a base to add these additional keywords to Scopus author keyword values already in the dictionary. After, the keywords (values) are de-duplicated. This step also generates an intermediary file (date_WMUresearcher_keywords_affiliation.csv), that exports all the keywords associated with a single researcher.
# <br></br>
# * <b>In[11]</b> Associates single research key with a single researcherID. \
# The researkey_dict is then transformed into singleresearkey_dict, where the research keyword list is split up into single units, and each keyword is associated with a researcher ID (W567898:[1,2,3] --> W567898:[1], W567898:[2], W567898:[3])
# <br></br>
# * <b>In[12]</b> Associate single research key with multiple researchIDs, and adds additional context to each researchID. \
# A new txt file is read into the script that associates researcher IDs with researcher name and WMU department | WMed department (researcher_affiliation). This is transformed into the uniqueIDaffil_dict, which is then used to add context to the keyresearaffil_dict, which links keywords to researcher IDs, researcher names, and researcher departments. All of the affiliation values are de-duplicated. Keyresear_dict is then transformed into a dataframe (keyresearaffil_dataframe) and the final file is exported (date_WMUresearcher_keywords_affiliation.csv) with a single keyword associated with multiple researchers.

# %% [markdown]
# Listing python libraries used within script

# %%
#used for querying the ScopusAPI
import pybliometrics 
from pybliometrics.scopus import ScopusSearch

#used to obtain today's date for file export
from datetime import date

#used to create dataframe for csv export
import pandas as pd

# %% [markdown]
# Listing files used as part of script

# %%
researcher_ScopusID_list = "ScopusID_complete-list.txt"
partialresearcher_ScopusID_list = "ScopusID_WMU-list.txt" 
researcher_articles_list = "2024-04-17_researcher-articles-complete.csv"
researcher_scopus = "researcherID_scopusID.txt"
researcher_additionalkeywords = "researcherID_additionalkeywords.txt"
researcher_affiliation = "researcherID_researcherdept.txt"

# %% [markdown]
# Initiating ScopusAPI pull for complete researcher ScopusIDs (WMU and Wmed)

# %%
#read in list with Scopus IDs from all researchers (WMU and Wmed)
IDs = open(researcher_ScopusID_list, 'r')
read_IDs = IDs.read().split(',')

#creating list adding AU-ID extension to the front of each ID, required for ScopusSearch
authors_ids = []
for id in read_IDs:
    new = "AU-ID(" + id + ")"
    authors_ids.append(new)

# %%
#initializing a dataframe outside the loop that will match the expected shape of the scopus pull
s = ScopusSearch(authors_ids[0])
df_articles_composite = pd.DataFrame(pd.DataFrame(s.results))

#looping through each ScopusID in list
for index, ID in enumerate(authors_ids):
    s = ScopusSearch(ID) #look up each ID in Scopus
    df_results = pd.DataFrame(pd.DataFrame(s.results)) #get all scholarship metadata associated with each ID
    if index != 0: #if scholarship is associated with ID
        df_articles_composite = pd.concat([df_articles_composite, df_results]) #concatenating to composite dataframe
    
#looking up today's date and exporting composite dataframe to comma separated value file with utf-8 encoding
todays_date = date.today()
df_articles_composite.to_csv(f"{todays_date.isoformat()}_researcher-articles-complete.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# Initiating ScopusAPI pull for WMU researcher ScopusIDs only

# %%
#read in list with Scopus IDs from WMU only (excluding WMed)
partialIDs = open(partialresearcher_ScopusID_list, 'r')
read_partialIDs = partialIDs.read().split(',')

#creating list adding AU-ID extension to the front of each ID, required for ScopusSearch
partial_authors_ids = []
for id in read_partialIDs:
    new = "AU-ID(" + id + ")"
    partial_authors_ids.append(new)

# %%
#initializing a dataframe outside the loop that will match the expected shape of the scopus pull
s = ScopusSearch(partial_authors_ids[0])
df_partialarticles_composite = pd.DataFrame(pd.DataFrame(s.results))

#looping through each ScopusID in list
for index, ID in enumerate(partial_authors_ids):
    s = ScopusSearch(ID) #look up each ID in Scopus
    df_results = pd.DataFrame(pd.DataFrame(s.results)) #get all scholarship metadata associated with each ID
    if index != 0: #check if there is scholarship associated with ScopusID
        df_partialarticles_composite = pd.concat([df_partialarticles_composite, df_results]) #concatenate to composite dataframe

#looking up today's date and exporting partial composite dataframe to comma separated value file with utf-8 encoding    
todays_date = date.today()
df_partialarticles_composite.to_csv(f"{todays_date.isoformat()}_researcher-articles-WMU.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# Importing back in the file of all articles associated with WMU and Wmed researchers indexed by Scopus

# %%
df_full_articles = pd.read_csv(researcher_articles_list,encoding='utf-8-sig')
df_full_articles #preview metadata associated with each piece of scholarship
# Out:
#                       eid                                 doi  \
# 0      2-s2.0-85141012738           10.1177/10982140211062884
# 1      2-s2.0-85138312850                                 NaN
# 2      2-s2.0-85150569347  10.1016/B978-0-12-818630-5.09052-7
# 3      2-s2.0-85050960472  10.1016/j.evalprogplan.2018.06.004
# 4      2-s2.0-85138417336           10.1017/9781107477261.011
# ...                   ...                                 ...
# 21792  2-s2.0-67649342663          10.5408/1089-9995-56.3.251
# 21793  2-s2.0-37349131275                10.1029/2007EO420009
# 21794  2-s2.0-29444432507                10.1029/2004JB003432
# 21795  2-s2.0-85046234249            10.1130/0-8137-0004-3.87
# 21796   2-s2.0-0346973940            10.1093/petrology/egg078
#
#                      pii   pubmed_id  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    NaN         NaN
# 3      S0149718917302331  30092490.0
# 4                    NaN         NaN
# ...                  ...         ...
# 21792                NaN         NaN
# 21793                NaN         NaN
# 21794                NaN         NaN
# 21795                NaN         NaN
# 21796                NaN         NaN
#
#                                                    title subtype  \
# 0      Thinking Outside the Self-Report: Using Evalua...      ar
# 1      Creating a collaborative cross-institutional c...      cp
# 2                 Metaevaluation: key concepts explained      ch
# 3      The project vita: A dynamic knowledge manageme...      ar
# 4                              Monitoring and Evaluation      ch
# ...                                                  ...     ...
# 21792  Geoscience conceptual knowledge of preservice ...      ar
# 21793  Geoscience faculty discuss courses for future ...      ar
# 21794  Modeling magma flow and cooling in dikes: Impl...      ar
# 21795  The Columbia River flood basalts and the Yakim...      ar
# 21796  Textural and thermal history of partial meltin...      ar
#
#       subtypeDescription        creator                                 afid  \
# 0                Article   Wingate L.A.          60001439;60000879;101288518
# 1       Conference Paper     Cervato C.                            128584608
# 2           Book Chapter   Wingate L.A.                             60000879
# 3                Article   Wingate L.A.                    60030551;60000879
# 4           Book Chapter   MacDonald G.                    60021658;60000879
# ...                  ...            ...                                  ...
# 21792            Article  Petcovic H.L.                             60000879
# 21793            Article     Manduca C.           60013250;60003631;60000879
# 21794            Article    Petcovic H.                    60015481;60000879
# 21795            Article    Reidel S.P.  60023471;60016326;60015120;60013402
# 21796            Article  Petcovic H.L.                             60013402
#
#                                                affilname  ...  pageRange  \
# 0      Pennsylvania State University;Western Michigan...  ...    515-538
# 1                                   Chemical Engineering  ...        NaN
# 2                            Western Michigan University  ...    263-274
# 3        Syracuse University;Western Michigan University  ...      22-27
# 4      Centers for Disease Control and Prevention;Wes...  ...    122-135
# ...                                                  ...  ...        ...
# 21792                        Western Michigan University  ...    251-260
# 21793  Carleton College, USA;Western Washington Unive...  ...        428
# 21794  University of Washington;Western Michigan Univ...  ...       1-15
# 21795  Pacific Northwest National Laboratory;Washingt...  ...     87-105
# 21796                            Oregon State University  ...  2287-2312
#
#                                              description  \
# 0      In this study, we investigated the impact of t...
# 1      NSF ADVANCE has been instrumental in supportin...
# 2      This article's purpose is to acquaint readers ...
# 3      A project vita is a comprehensive index of fac...
# 4                                                    NaN
# ...                                                  ...
# 21792  Effective instruction hinges in part on unders...
# 21793                                                NaN
# 21794  The Columbia River flood basalts include some ...
# 21795  This field trip guide covers a two-day trip to...
# 21796  Columbia River Basalt Group dikes invade bioti...
#
#                                             authkeywords citedby_count  \
# 0      evaluation capacity building | evaluation trai...             0
# 1                                                    NaN             2
# 2      Evaluation quality | Evaluation standards | Me...             0
# 3      Accountability | Center | Evaluation | Knowled...             7
# 4                                                    NaN             0
# ...                                                  ...           ...
# 21792                                                NaN            25
# 21793                                                NaN             0
# 21794                                                NaN            65
# 21795                                                NaN            16
# 21796  Columbia River Basalt dike | Crustal melting |...            48
#
#       openaccess          freetoread freetoreadLabel fund_acr    fund_no  \
# 0              0                 NaN             NaN      NSF    1600992
# 1              0                 NaN             NaN      NSF    1935932
# 2              0                 NaN             NaN      NaN  undefined
# 3              1  publisherfree2read          Bronze      NSF    1600992
# 4              0                 NaN             NaN      NaN  undefined
# ...          ...                 ...             ...      ...        ...
# 21792          0                 NaN             NaN      NaN  undefined
# 21793          1  publisherfree2read          Bronze      NaN  undefined
# 21794          0                 NaN             NaN      NaN  undefined
# 21795          0                 NaN             NaN      NaN  undefined
# 21796          1        repositoryam           Green      GSA    6514-99
#
#                         fund_sponsor
# 0        National Science Foundation
# 1        National Science Foundation
# 2                                NaN
# 3        National Science Foundation
# 4                                NaN
# ...                              ...
# 21792                            NaN
# 21793                            NaN
# 21794                            NaN
# 21795                            NaN
# 21796  Geological Society of America
#
# [21797 rows x 36 columns]

# %% [markdown]
# Using the full Scopus article file to match rows on ScopusIDs, and then extracting author keywords associated with each row to create a dictionary associating ScopusID to author keywords within indexed articles

# %%
#creating ScopusID:authorkeyword dictionary outside of loop
aukey_dict = {}

#removing AU-ID extension from the front of each ScopusID and saving to new list
stripped_author_ids = [id.strip("AU-ID(").strip(")") for id in authors_ids]

#creating placeholder keyword list to concatenate keywords across articles for each ScopusID
keyword_list = []
#looping through each ID in newly created list
for id in stripped_author_ids:
    id_matched_rows = df_full_articles['author_ids'].str.contains(id) #checking ScopusID in list against ScopusID in row
    id_matched_keywords = df_full_articles[id_matched_rows]['authkeywords'] #grabbing author keywords from matched row
    massaged_keywords_list_list = id_matched_keywords.str.replace(" | ",",",regex=False).str.lower().str.split(",") #changing author keywords from string to list
    for row in massaged_keywords_list_list:
        if row: #checking if the row is not an empty list (an empty list in python is considered False)
            if type(row) == type([]): #if the row is empty, the id didn't match any articles
                #if the id did match an article, but there were no keywords provided then the result is nan (which would cause an error with the extend method)
                keyword_list.extend(row) #adding keywords to placeholder keyword list
    aukey_dict[id] = keyword_list #creating key:value pairs in dictionary
    keyword_list = [] #clearing placeholder list
    
aukey_dict #preview as proof of concept
# Out:
# {'9846499400': ['evaluation capacity building',
#   'evaluation training',
#   'interrupted time series',
#   'professional development',
#   'evaluation quality',
#   'evaluation standards',
#   'meta-evaluation',
#   'metaevaluation',
#   'metaevaluation criteria',
#   'metaevaluation methods',
#   'program evaluation',
#   'accountability',
#   'center',
#   'evaluation',
#   'knowledge management',
#   'research and development',
#   'resume',
#   'vita',
#   'evaluation',
#   'formative evaluation',
#   'government auditing standards',
#   'guiding principles for evaluators',
#   'meta-evaluation',
#   'program evaluation',
#   'program evaluation standards',
#   'summative evaluation',
#   'evaluation',
#   'formative evaluation',
#   'government auditing standards',
#   'guiding principles for evaluators',
#   'meta-evaluation',
#   'program evaluation',
#   'program evaluation standards',
#   'summative evaluation',
#   'evaluation quality',
#   'evaluation standards',
#   'meta-evaluation',
#   'metaevaluation',
#   'metaevaluation criteria',
#   'metaevaluation methods',
#   'program evaluation'],
#  '9437153000': ['active learning',
#   'distance learning',
#   'entrepreneurship',
#   'materials science',
#   'active learning',
#   'design thinking',
#   'engineering thinking',
#   'hands-on design',
#   'additive manufacturing',
#   'recycling and composites',
#   'sustainability',
#   'tribology',
#   'carbon fiber-reinforced polymers',
#   'fatigue model',
#   'fatigue test',
#   'four-point bending',
#   'stiffness degradation',
#   'continuous fiber-reinforced composites',
#   'failure theories',
#   'unidirectional lamina',
#   'world wide failure exercise (wwfe)',
#   'au-12ge interlayer',
#   'diffusion bonding',
#   'microstructure',
#   'tensile strength',
#   'tlp bonding',
#   'fracture toughness',
#   'glass fibers',
#   'mechanical testing',
#   'out of autoclave manufacturing',
#   'wind turbine blades',
#   'austenitic stainless steels',
#   'fracture',
#   'hydrogen embrittlement',
#   'composite repairs',
#   'fracture toughness',
#   'glass-fiber composites',
#   'mixed-mode testing',
#   'out-of-autoclave',
#   'bending fatigue',
#   'buckling',
#   'failure transition',
#   'fatigue testing',
#   'glass fiber-reinforced polymers',
#   'diffusion bonding',
#   'doe',
#   'joint microstructure',
#   'joint strength',
#   'nickel alloys',
#   'carbon fiber reinforced polymer (cfrp)',
#   'fatigue life',
#   'four point bending test',
#   'dictra',
#   'diffusion joint',
#   'interdiffusion',
#   'modeling',
#   'ni-cu',
#   'diffusion joint',
#   'liquid phase bonding',
#   'microstructure',
#   'tensile strength',
#   'dictra',
#   'diffusion joint',
#   'interdiffusion',
#   'diffusion bonding',
#   'microstructure',
#   'tensile strength',
#   'titanium',
#   'catalyst particles',
#   'mechanical milling',
#   'pollution control',
#   'polymer fabric filters',
#   'a. polymer-matrix composites',
#   'a. structural materials',
#   'b. modeling',
#   'c. laminate theory',
#   'cohesive-zone modelling',
#   'finite element modelling',
#   'fracture',
#   'resistance spot-welding',
#   'adhesively bonded joints',
#   'aluminum alloy 5754',
#   'cohesive-zone models',
#   'deformation fracture',
#   'spot welded joints',
#   'weld-bonded joints',
#   'asphalt',
#   'cracking',
#   'embrittlement',
#   'reversible hardening',
#   'steric hardening',
#   'cohesive strength',
#   'cohesive-zone',
#   'damage nucleation',
#   'double-cantilever beam',
#   'linear-elastic fracture mechanics'],
#  '8976007500': ['carbon criminals',
#   'climate change',
#   'climate change action plan',
#   'global heating',
#   'green criminology',
#   'state-corporate crime',
#   'climate change',
#   'denial',
#   'global warming',
#   'political economy',
#   'power',
#   'state-corporate crime'],
#  '8964440300': ['courts of appeals',
#   'judicial decision making',
#   'judicial policy making',
#   'presidential nomination',
#   'presidential success',
#   'amicus curiae',
#   'coalitions',
#   'disadvantaged groups',
#   'gender',
#   'interest groups',
#   'lobbying',
#   'race',
#   'supreme court'],
#  '8934184500': ['autonomy',
#   'coordinated',
#   'exams',
#   'institutional change',
#   'stem',
#   'textbook',
#   'undergraduate',
#   'engineering education',
#   'jeffrey froyd',
#   'memory',
#   'stem education',
#   'tributes',
#   'beliefs about teaching',
#   'chemistry',
#   'contextual factors',
#   'evidence-based instructional practices',
#   'institutional change',
#   'mathematics',
#   'personal factors',
#   'physics',
#   'teaching practices',
#   'undergraduate education',
#   'active learning',
#   'beliefs about teaching',
#   'contextual factors',
#   'evidence-based instructional practices',
#   'institutional change',
#   'personal factors',
#   'research-based instructional strategies',
#   'goals',
#   'medical education',
#   'student perceptions',
#   'team-based learning',
#   'calculus',
#   'individual characteristics',
#   'instructional practices',
#   'stem',
#   'faculty',
#   'grounded theory',
#   'instructional change',
#   'leadership',
#   'stem',
#   'teams',
#   'design',
#   'design-based science',
#   'idea communication',
#   'productive conversations',
#   'science learning',
#   'grading',
#   'physics education research',
#   'problem solving',
#   'professional development',
#   'teaching assistants',
#   'education policy',
#   'mismatch of policy and practice',
#   'program evaluation',
#   'sustainability',
#   'sustainability curriculum',
#   'higher education',
#   'instructional change',
#   'organizational change',
#   'teams',
#   'higher education change',
#   'higher education leadership',
#   'social network analysis',
#   'discipline-based education research',
#   'faculty evaluation',
#   'promotion',
#   'tenure',
#   'assessment',
#   'grading',
#   'problem solving',
#   'rubric',
#   'teaching assistants',
#   'change in higher education',
#   'dissemination',
#   'educational innovations',
#   'propagation',
#   'broader impacts',
#   'diffusion',
#   'dissemination',
#   'educational innovations',
#   'effective propagation strategies',
#   'proposal writing',
#   'transfer of innovation',
#   'active learning',
#   'factor analysis',
#   'instructional methods',
#   'student resistance',
#   'active learning',
#   'engagement',
#   'instructional methods',
#   'regression modeling',
#   'active learning spaces',
#   'classroom design',
#   'modifying education innovation',
#   'scale-up',
#   'studio-style instruction',
#   'change theory',
#   'educational innovations',
#   'effective propagation strategies',
#   'instructional system',
#   'proposal writing',
#   'faculty self-report',
#   'instruments',
#   'postsecondary',
#   'teaching practices',
#   'educational change',
#   'faculty',
#   'higher education',
#   'social network analysis',
#   'active learning',
#   'observation',
#   'student resistance',
#   'cognitive science',
#   'discipline-based education research',
#   'physics education research',
#   'research-based instructional strategies',
#   'stem undergraduate instruction',
#   'active learning',
#   'instructional strategies',
#   'observation',
#   'student resistance',
#   'active indicator',
#   'change agent',
#   'early adopter',
#   'past user',
#   'secondary site',
#   'astronomy',
#   'support',
#   'women in physics',
#   'women in science',
#   'work/life balance',
#   'curriculum change',
#   'instructional change',
#   'theories of change',
#   'engineering science',
#   'faculty beliefs',
#   'research-based instructional strategies',
#   'statics',
#   'engineering science',
#   'fidelity of implementation',
#   'research-based instructional strategies (rbis)',
#   'chemistry',
#   'earth science',
#   'faculty development',
#   'grading',
#   'physics',
#   'quantitative problem solving',
#   'change in engineering education',
#   'diffusion of innovations',
#   'faculty adoption',
#   'faculty awareness',
#   'research-based instructional strategies (rbiss)',
#   'teaching',
#   'feminism',
#   'gender',
#   'gender gap',
#   'grounded theory',
#   'women in physics',
#   'educational change',
#   'higher education.',
#   'social network analysis',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'diffusion of innovation',
#   'engineering sciences',
#   'innovation-decision process',
#   'problem solutions',
#   'problem solving',
#   'teachers beliefs',
#   'teaching assistants',
#   'communities of practice',
#   'diffusion of innovations',
#   'dissemination',
#   'leadership',
#   'modeling instruction',
#   'problem solutions',
#   'problem solving',
#   "teachers' beliefs",
#   'teaching assistants',
#   'funding',
#   'physics education research',
#   'dissemination',
#   'faculty development',
#   'introductory courses',
#   'assessment of teaching effectiveness',
#   'educational change',
#   'advanced technological education centers',
#   'college-program relationship',
#   'core competencies',
#   'program effectiveness',
#   'program outcomes',
#   'higher education',
#   'pedagogy',
#   'professional development',
#   'science education',
#   'teacher change',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'faculty development',
#   'introductory physics',
#   'peer instruction',
#   'dissemination',
#   'faculty development',
#   'introductory courses',
#   'peer instruction',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'high school',
#   'educational change',
#   'higher education',
#   'self-directed learning',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'centripetal force',
#   'circular motion',
#   'demo',
#   'laboratory',
#   'mbl',
#   'ow-cost',
#   'autonomy',
#   'coordinated',
#   'exams',
#   'institutional change',
#   'stem',
#   'textbook',
#   'undergraduate',
#   'beliefs about teaching',
#   'chemistry',
#   'contextual factors',
#   'evidence-based instructional practices',
#   'institutional change',
#   'mathematics',
#   'personal factors',
#   'physics',
#   'teaching practices',
#   'undergraduate education',
#   'active learning',
#   'beliefs about teaching',
#   'contextual factors',
#   'evidence-based instructional practices',
#   'institutional change',
#   'personal factors',
#   'research-based instructional strategies',
#   'calculus',
#   'individual characteristics',
#   'instructional practices',
#   'stem',
#   'active learning spaces',
#   'classroom design',
#   'modifying education innovation',
#   'scale-up',
#   'studio-style instruction',
#   'active indicator',
#   'change agent',
#   'early adopter',
#   'past user',
#   'secondary site',
#   'communities of practice',
#   'diffusion of innovations',
#   'dissemination',
#   'leadership',
#   'modeling instruction',
#   'dissemination',
#   'faculty development',
#   'introductory courses',
#   'assessment of teaching effectiveness',
#   'educational change',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'faculty development',
#   'introductory physics',
#   'peer instruction',
#   'dissemination',
#   'faculty development',
#   'introductory courses',
#   'peer instruction',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'high school',
#   'educational change',
#   'higher education',
#   'self-directed learning',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'goals',
#   'medical education',
#   'student perceptions',
#   'team-based learning',
#   'faculty',
#   'grounded theory',
#   'instructional change',
#   'leadership',
#   'stem',
#   'teams',
#   'higher education',
#   'instructional change',
#   'organizational change',
#   'teams',
#   'faculty self-report',
#   'instruments',
#   'postsecondary',
#   'teaching practices',
#   'higher education',
#   'pedagogy',
#   'professional development',
#   'science education',
#   'teacher change',
#   'educational change',
#   'higher education',
#   'dissemination',
#   'educational change',
#   'higher education',
#   'feminism',
#   'gender',
#   'gender gap',
#   'grounded theory',
#   'women in physics',
#   'faculty self-report',
#   'instruments',
#   'postsecondary',
#   'teaching practices',
#   'astronomy',
#   'support',
#   'women in physics',
#   'women in science',
#   'work/life balance',
#   'goals',
#   'medical education',
#   'student perceptions',
#   'team-based learning',
#   'chemistry',
#   'earth science',
#   'faculty development',
#   'grading',
#   'physics',
#   'quantitative problem solving',
#   'advanced technological education centers',
#   'college-program relationship',
#   'core competencies',
#   'program effectiveness',
#   'program outcomes'],
#  '58888049100': ['active learning',
#   'departmental change',
#   'grounded theory',
#   'instructional change',
#   'model development',
#   'undergraduate education',
#   'collaborative/cooperative learning',
#   'first-year undergraduate/general',
#   'active learning',
#   'departmental change',
#   'grounded theory',
#   'instructional change',
#   'model development',
#   'undergraduate education',
#   'collaborative/cooperative learning',
#   'first-year undergraduate/general'],
#  '8930414700': ['early career teachers',
#   'mathematics teacher identity',
#   'middle school',
#   'working community',
#   'classroom discourse',
#   'instructional activities and practices',
#   'mathematics',
#   'secondary',
#   'student thinking',
#   'teacher moves',
#   'teacher responses',
#   'mathematics',
#   'mathematics teaching methods and classroom techniques',
#   'responsive teaching',
#   'teacher responses',
#   'teaching practice',
#   'building on student thinking',
#   'student mathematical thinking',
#   'teacher beliefs',
#   'teacher orientations',
#   'using student thinking',
#   'ambiguity',
#   'discourse',
#   'classroom mathematics discourse',
#   'professional development',
#   'student mathematical thinking',
#   'teachable moments',
#   'teaching practice',
#   'practice',
#   'research on teaching',
#   'teacher beliefs',
#   'teacher identity',
#   'teacher knowledge',
#   'beginning teachers',
#   'mathematics teacher education',
#   'student thinking',
#   'teachable moments',
#   'teacher decisions',
#   'mathematics pedagogy course',
#   'norm durability',
#   'professional norms',
#   'sociomathematical norms',
#   'teacher education',
#   'video-case curriculum',
#   'beginning teachers',
#   'pedagogical practices',
#   'student thinking',
#   'feedback (response)',
#   'mathematics education',
#   'preservice teacher',
#   'scaffolding (teaching technique)',
#   'self-evaluation (individuals)',
#   'teacher education'],
#  '8870487100': ['assurance case',
#   'autonomous driving',
#   'mape-k',
#   'self-adaptive system',
#   'fuzzing',
#   'reliability',
#   'security',
#   'software testing',
#   'survey',
#   'dempster-shafer theory',
#   'software certification',
#   'software traceability',
#   'vector space model (vsm)',
#   'assurance case',
#   'model transformation',
#   'safety critical systems',
#   'safety pattern',
#   'class diagram',
#   'compliance checking',
#   'conformance checking',
#   'instance diagram',
#   'international codes',
#   'assurance model',
#   'model transformation',
#   'safety critical system',
#   'safety pattern',
#   'class diagrams',
#   'java',
#   'model checking',
#   'uml',
#   'cyber-physical system',
#   'model transformation',
#   'resiliency',
#   'safety-critical systems',
#   'simulink',
#   'trustworthiness',
#   'assurance model',
#   'medical device software',
#   'model transformation',
#   'safety critical system',
#   'safety pattern',
#   'assurance cases',
#   'medical device software',
#   'ocl',
#   'safety critical system',
#   'uml profile',
#   'bug localization',
#   'stack traces',
#   'static analysis',
#   'text retrieval',
#   'class diagram',
#   'java',
#   'model checking',
#   'uml',
#   'medical device software',
#   'ocl',
#   'regulaotry review',
#   'safety critical system',
#   'uml profile',
#   'hazard analysis',
#   'regulatory reviews',
#   'traceability',
#   'black-box testing',
#   'formal specification',
#   'specification-based testing',
#   'component',
#   'composition',
#   'modeling',
#   'ownership',
#   'uml',
#   'loop-extended',
#   'model checking',
#   'symbolic execution',
#   'compiler',
#   'metamorphic testing',
#   'test automation',
#   'test input generation',
#   'test oracle',
#   'class diagram',
#   'eclipse',
#   'model checker',
#   'ownership',
#   'uml',
#   'class models',
#   'consistency checking',
#   'refinement',
#   'separation of concerns and uml',
#   'design pattern',
#   'pattern conformance',
#   'rbml',
#   'uml',
#   'message passing',
#   'sequence diagram',
#   'state chart diagram',
#   'uml',
#   'abstract state machines',
#   'model checking'],
#  '8855390600': ['climate control',
#   'covid-19 pandemic',
#   'ethnicity',
#   'food insecurity',
#   'gender',
#   'health disparities',
#   'health equity',
#   'health inequities',
#   'housing instability',
#   'integrated behavioral health',
#   'lgbt persons',
#   'medical training curricula',
#   'pediatrics',
#   'peer health navigators',
#   'poverty',
#   'race',
#   'rural communities',
#   'social determinants of health',
#   'socioeconomic status',
#   'adnexal mass',
#   'adolescents',
#   'germ-cell tumor',
#   'ovarian mass',
#   'ovarian tumor',
#   'pediatrics',
#   'amputee athletes',
#   'atlantoaxial instability',
#   'autonomic dysreflexia',
#   'behavioral aspects',
#   'blood doping',
#   'boosting',
#   'disabled athletes',
#   'down syndrome',
#   'ergolytic drugs',
#   'gene doping',
#   'intellectual disability',
#   'mental health of athletes',
#   'pediatric sports medicine',
#   'reaction to injuries',
#   'sports attrition',
#   'sports doping',
#   'wheelchair athletes',
#   'mortality',
#   'obstructive and central sleep apnea (osa and csa)',
#   'prader-willi syndrome (pws)',
#   'respiratory failure',
#   'adult height',
#   'central precocious puberty (cpp)',
#   'gnrh agonists',
#   'menarche',
#   'antidiabetic agents 50',
#   'insulin',
#   'obesity',
#   'polycystic ovary syndrome (pcos)',
#   'type 1 diabetes (t1d)',
#   '11β-hydroxylase deficiency',
#   'congenital adrenal hyperplasia',
#   'cyp11b1',
#   'gene',
#   'genotype-phenotype',
#   'novel cyp11b1 mutation',
#   'gonadal differentiation',
#   'sex determination',
#   'sry gene',
#   'xx maleness',
#   'endogenous insulin reserve',
#   'gad 65',
#   'hla-dr/dq phenotypes',
#   'ia-2 autoantibodies',
#   'immune-mediated diabetes',
#   'insulin antoantibodies',
#   'islet cell autoantibodies (ica)',
#   'mixed meal tolerance testing',
#   'oral insulin tolerance therapy',
#   'type 1 diabetes',
#   'climate control',
#   'covid-19 pandemic',
#   'ethnicity',
#   'food insecurity',
#   'gender',
#   'health disparities',
#   'health equity',
#   'health inequities',
#   'housing instability',
#   'integrated behavioral health',
#   'lgbt persons',
#   'medical training curricula',
#   'pediatrics',
#   'peer health navigators',
#   'poverty',
#   'race',
#   'rural communities',
#   'social determinants of health',
#   'socioeconomic status',
#   'adnexal mass',
#   'adolescents',
#   'germ-cell tumor',
#   'ovarian mass',
#   'ovarian tumor',
#   'pediatrics',
#   'amputee athletes',
#   'atlantoaxial instability',
#   'autonomic dysreflexia',
#   'behavioral aspects',
#   'blood doping',
#   'boosting',
#   'disabled athletes',
#   'down syndrome',
#   'ergolytic drugs',
#   'gene doping',
#   'intellectual disability',
#   'mental health of athletes',
#   'pediatric sports medicine',
#   'reaction to injuries',
#   'sports attrition',
#   'sports doping',
#   'wheelchair athletes',
#   'adult height',
#   'central precocious puberty (cpp)',
#   'gnrh agonists',
#   'menarche',
#   'climate control',
#   'covid-19 pandemic',
#   'ethnicity',
#   'food insecurity',
#   'gender',
#   'health disparities',
#   'health equity',
#   'health inequities',
#   'housing instability',
#   'integrated behavioral health',
#   'lgbt persons',
#   'medical training curricula',
#   'pediatrics',
#   'peer health navigators',
#   'poverty',
#   'race',
#   'rural communities',
#   'social determinants of health',
#   'socioeconomic status',
#   'adult height',
#   'central precocious puberty (cpp)',
#   'gnrh agonists',
#   'menarche',
#   'amputee athletes',
#   'atlantoaxial instability',
#   'autonomic dysreflexia',
#   'behavioral aspects',
#   'blood doping',
#   'boosting',
#   'disabled athletes',
#   'down syndrome',
#   'ergolytic drugs',
#   'gene doping',
#   'intellectual disability',
#   'mental health of athletes',
#   'pediatric sports medicine',
#   'reaction to injuries',
#   'sports attrition',
#   'sports doping',
#   'wheelchair athletes',
#   'climate control',
#   'covid-19 pandemic',
#   'ethnicity',
#   'food insecurity',
#   'gender',
#   'health disparities',
#   'health equity',
#   'health inequities',
#   'housing instability',
#   'integrated behavioral health',
#   'lgbt persons',
#   'medical training curricula',
#   'pediatrics',
#   'peer health navigators',
#   'poverty',
#   'race',
#   'rural communities',
#   'social determinants of health',
#   'socioeconomic status',
#   'amputee athletes',
#   'atlantoaxial instability',
#   'autonomic dysreflexia',
#   'behavioral aspects',
#   'blood doping',
#   'boosting',
#   'disabled athletes',
#   'down syndrome',
#   'ergolytic drugs',
#   'gene doping',
#   'intellectual disability',
#   'mental health of athletes',
#   'pediatric sports medicine',
#   'reaction to injuries',
#   'sports attrition',
#   'sports doping',
#   'wheelchair athletes',
#   'climate control',
#   'covid-19 pandemic',
#   'ethnicity',
#   'food insecurity',
#   'gender',
#   'health disparities',
#   'health equity',
#   'health inequities',
#   'housing instability',
#   'integrated behavioral health',
#   'lgbt persons',
#   'medical training curricula',
#   'pediatrics',
#   'peer health navigators',
#   'poverty',
#   'race',
#   'rural communities',
#   'social determinants of health',
#   'socioeconomic status'],
#  '8781263700': [],
#  '8750736500': ['infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'child injuries',
#   'child injury prevention',
#   'covid-19',
#   'prevention',
#   'virtual data collection',
#   'early childhood',
#   'home visiting',
#   'provider-client alliance',
#   'visitas a casa',
#   'education',
#   'intervention',
#   'parenting',
#   'prevention',
#   'primary care',
#   'spanking',
#   'home visiting services',
#   'infant mortality',
#   'infant safe sleep',
#   'motivational interviewing',
#   'child injuries',
#   'cultural modification',
#   'injury prevention',
#   'supervision',
#   'caregiver supervision',
#   'cell phones',
#   'child injuries',
#   'pseudo hazards',
#   'early childhood development',
#   'economic disadvantage',
#   'language',
#   'physical health',
#   'social-emotional',
#   'child maltreatment',
#   'delinquency',
#   'longscan',
#   'child injuries',
#   'injury prevention',
#   'marital satisfaction',
#   'maternal supervision',
#   'child deaths',
#   'child maltreatment',
#   'child maltreatment fatalities',
#   'engagement in services',
#   'home visiting services',
#   'postpartum',
#   'pregnancy',
#   'child abuse and neglect',
#   'evidence-based practice',
#   'home visiting',
#   'parenting',
#   'unintentional injury',
#   'case crossover design',
#   'child injuries',
#   'maternal supervision',
#   'adolescent',
#   'adult survivor',
#   'children',
#   'maltreatment',
#   'trauma',
#   'child abuse',
#   'family issues and mediators',
#   'neglect',
#   'child injuries',
#   'injury prevention',
#   'interventions',
#   'child injury prevention',
#   'maternal supervision',
#   'child abuse',
#   'child fatalities',
#   'child neglect',
#   'caregiver supervision',
#   'fathers',
#   'unintentional child injury',
#   'advocacy',
#   'college access',
#   'foster care',
#   'public policy',
#   'youth in transition',
#   'youth voice',
#   'cultural/ethnic issues',
#   'home-based services',
#   'treatment',
#   'college retention and graduation',
#   'foster youth',
#   'post-secondary education',
#   'transition to adulthood',
#   'child abuse',
#   'education and training',
#   'child sexual abuse',
#   'emotional/psychological maltreatment',
#   'evidence-based treatment',
#   'home visiting',
#   'neglect',
#   'prevention',
#   'service delivery',
#   'child deaths',
#   'child maltreatment fatalities',
#   'caregiver alcohol use',
#   'caregiver supervision',
#   'child injuries',
#   'unintentional injury',
#   'children',
#   'parental locus of control',
#   'prevention',
#   'risky behavior',
#   'unintentional injury',
#   'child abuse',
#   'child maltreatment',
#   'parenting',
#   'sexual abuse',
#   'child',
#   'injury',
#   'prevention',
#   'baby walker',
#   'exersaucer',
#   'parental supervision',
#   'advocacy',
#   'college access',
#   'foster care',
#   'public policy',
#   'youth in transition',
#   'youth voice',
#   'college retention and graduation',
#   'foster youth',
#   'post-secondary education',
#   'transition to adulthood',
#   'infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'home visiting services',
#   'infant mortality',
#   'infant safe sleep',
#   'motivational interviewing',
#   'infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'home visiting services',
#   'infant mortality',
#   'infant safe sleep',
#   'motivational interviewing',
#   'infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'early childhood',
#   'home visiting',
#   'provider-client alliance',
#   'visitas a casa',
#   'engagement in services',
#   'home visiting services',
#   'postpartum',
#   'pregnancy'],
#  '8600584500': ['high-fidelity simulation',
#   'knowledge gain',
#   'knowledge retention',
#   'nursing education',
#   'attitudes',
#   'experiential learning',
#   'nursing students',
#   'poverty',
#   'social justice'],
#  '8581808900': ['elevated precipitation',
#   'microbial functional trait',
#   'resource acquisition',
#   'soil carbon loss',
#   'viral shunt',
#   'water-limited ecosystems',
#   'climate change',
#   'microbial community',
#   'next-generation sequencing',
#   'prairie',
#   'restoration',
#   'soil',
#   'geochip',
#   'global change',
#   'high-throughput sequencing',
#   'nitrogen deposition',
#   'soil microbial community',
#   'fire severity',
#   'microbial community composition',
#   'microbial metabolism',
#   'soil carbon pools',
#   'soil carbon stability',
#   '16s rrna',
#   'airborne bacteria',
#   'altitude',
#   'land use',
#   'trajectories',
#   'forest soils',
#   'microbial community composition',
#   'microbial community structure',
#   'microbial diversity',
#   'soil properties',
#   'californian grasslands',
#   'climate change',
#   'fire',
#   'geochip',
#   'high-throughput sequencing',
#   'microbial communities',
#   'anoxia',
#   'deicer',
#   'eutrophication',
#   'methane',
#   'redox stratification',
#   'road salt',
#   'bacteria',
#   'climate',
#   'fungi',
#   'microbe',
#   'prairie',
#   'restoration',
#   'soil',
#   'temperature',
#   'annual grassland',
#   'elevated co 2',
#   'geochip',
#   'microbial communities',
#   'miseq sequencing',
#   '16s rrna',
#   'atmosphere',
#   'bacteria',
#   'community',
#   'microbe',
#   'sampler',
#   'antibiotic resistant bacteria',
#   'birds',
#   'land use',
#   'wildlife',
#   'brood patch',
#   'leach’s storm petrel',
#   'skin microbiome',
#   'uropygial gland',
#   'biodegradation',
#   'ionic liquid',
#   'mass spectrometry',
#   'microbial community',
#   'nmr spectroscopy',
#   'wastewater',
#   'biodegradation',
#   'ionic liquids',
#   'microbial',
#   'proactive',
#   'wastewater',
#   'fire',
#   'global change',
#   'grassland',
#   'plfa',
#   'soil microbiology',
#   'aquatic toxicology',
#   'bioassay',
#   'ecotoxicology',
#   'interdisciplinary collaboration',
#   'mesocosm',
#   'green chemistry',
#   'imidazolium',
#   'ionic liquids',
#   'microbial biodegradability',
#   'pyridinium',
#   'biodegradation',
#   'dissolved organic matter',
#   'microbial community',
#   'biodegradation',
#   'dissolved organic matter',
#   'hpsec',
#   'antibiotic resistant bacteria',
#   'birds',
#   'land use',
#   'wildlife',
#   'anoxia',
#   'deicer',
#   'eutrophication',
#   'methane',
#   'redox stratification',
#   'road salt',
#   'biodegradation',
#   'ionic liquid',
#   'mass spectrometry',
#   'microbial community',
#   'nmr spectroscopy',
#   'wastewater',
#   'antibiotic resistant bacteria',
#   'birds',
#   'land use',
#   'wildlife',
#   'antibiotic resistant bacteria',
#   'birds',
#   'land use',
#   'wildlife',
#   '16s rrna',
#   'airborne bacteria',
#   'altitude',
#   'land use',
#   'trajectories',
#   '16s rrna',
#   'atmosphere',
#   'bacteria',
#   'community',
#   'microbe',
#   'sampler'],
#  '8548434800': ['cell biology',
#   'immunology',
#   'aging',
#   'b-1 cell',
#   'biological sex',
#   'natural antibody',
#   'phosphatidylcholine',
#   'aging',
#   'atherosclerosis',
#   'b-1 cells',
#   'ccr6',
#   'ighv sequencing',
#   'igm antibodies',
#   'inflammation',
#   'atherosclerosis',
#   'bone marrow',
#   'cardiovascular disease',
#   'immunoglobulin m',
#   'inflammation',
#   'acute lung injury',
#   'b-1a cells',
#   'il-10',
#   'inflammation',
#   'neutrophils',
#   'sepsis',
#   'antibodies',
#   'b cells',
#   'b-1 cells',
#   'natural antibodies',
#   'natural antibodies repertoire',
#   'antibodies',
#   'b cell subsets',
#   'b cells',
#   'b-1 cells',
#   'natural antibody',
#   'natural antibody repertoire',
#   'aid',
#   'b-1 cell subset',
#   'b-1a cells',
#   'cd25',
#   'peritoneal cavity',
#   'activation',
#   'antigen presentation',
#   'autoantibody',
#   'b cells',
#   'b-1 cells',
#   'b-2 cells',
#   'immunosuppression',
#   'natural antibody',
#   'phagocytosis',
#   'proinflammatory th17 cells',
#   'signaling',
#   'autoimmunity',
#   'b cells',
#   'b-1 cells',
#   'lupus erythematosus',
#   'mouse model',
#   'natural antibodies',
#   'repertoire analysis',
#   'systemic',
#   'b cell repertoire',
#   'id3 −/−',
#   'salivary gland',
#   'sialadenitis',
#   'aging',
#   'b cells',
#   'b-1 cells',
#   'senescence',
#   'atherosclerosis',
#   'autoimmunity',
#   'b-1 cells',
#   'ibd',
#   'inflammation',
#   'influenza',
#   'natural igm',
#   'sepsis',
#   'antibody',
#   'b lymphocytes',
#   'b-1 cells',
#   'igm',
#   'b cells',
#   'protein kinases/phosphatases',
#   'rodent',
#   'signal transduction',
#   'antibody',
#   'b cells',
#   'b-1',
#   'lymphocytes',
#   'b1 cells',
#   'cd25',
#   'lif receptor',
#   'signaling',
#   'antibodies',
#   'b cells',
#   'cell differentiation',
#   'spleen',
#   'transcription factors',
#   'antibodies',
#   'b cells',
#   'cell differentiation',
#   'repertoire development',
#   'b cells',
#   'protein kinases/phosphatases',
#   'rodent',
#   'signal transduction',
#   'b cells immunoglobulins',
#   'molecular biology',
#   'recombinant viral vectors',
#   'apoptosis',
#   'caspase-1',
#   'iga deficiency',
#   'immunodeficiency diseases',
#   'cell biology',
#   'immunology',
#   'aging',
#   'atherosclerosis',
#   'b-1 cells',
#   'ccr6',
#   'ighv sequencing',
#   'igm antibodies',
#   'inflammation',
#   'atherosclerosis',
#   'bone marrow',
#   'cardiovascular disease',
#   'immunoglobulin m',
#   'inflammation',
#   'acute lung injury',
#   'b-1a cells',
#   'il-10',
#   'inflammation',
#   'neutrophils',
#   'sepsis',
#   'aid',
#   'b-1 cell subset',
#   'b-1a cells',
#   'cd25',
#   'peritoneal cavity',
#   'activation',
#   'antigen presentation',
#   'autoantibody',
#   'b cells',
#   'b-1 cells',
#   'b-2 cells',
#   'immunosuppression',
#   'natural antibody',
#   'phagocytosis',
#   'proinflammatory th17 cells',
#   'signaling',
#   'autoimmunity',
#   'b cells',
#   'b-1 cells',
#   'lupus erythematosus',
#   'mouse model',
#   'natural antibodies',
#   'repertoire analysis',
#   'systemic',
#   'b cell repertoire',
#   'id3 −/−',
#   'salivary gland',
#   'sialadenitis',
#   'aging',
#   'b cells',
#   'b-1 cells',
#   'senescence',
#   'atherosclerosis',
#   'autoimmunity',
#   'b-1 cells',
#   'ibd',
#   'inflammation',
#   'influenza',
#   'natural igm',
#   'sepsis',
#   'antibody',
#   'b lymphocytes',
#   'b-1 cells',
#   'igm',
#   'b cells',
#   'protein kinases/phosphatases',
#   'rodent',
#   'signal transduction',
#   'antibody',
#   'b cells',
#   'b-1',
#   'lymphocytes',
#   'b1 cells',
#   'cd25',
#   'lif receptor',
#   'signaling',
#   'antibodies',
#   'b cells',
#   'cell differentiation',
#   'spleen',
#   'transcription factors',
#   'antibodies',
#   'b cells',
#   'cell differentiation',
#   'repertoire development',
#   'b cells',
#   'protein kinases/phosphatases',
#   'rodent',
#   'signal transduction',
#   'b cells immunoglobulins',
#   'molecular biology',
#   'recombinant viral vectors'],
#  '8515540200': ['coupled wind-wave testing',
#   'distributed real-time hybrid testing',
#   'dynamic response evaluation',
#   'floating wind turbine',
#   'model experiments',
#   'critical delay',
#   'critical gain',
#   'nonlinearity',
#   'real-time hybrid simulation',
#   'relative stability',
#   'high-frequency signals',
#   'rpo',
#   'rths',
#   'time delay',
#   'vehicle-bridge coupling system',
#   'ats+lqg',
#   'high-frequency signals',
#   'rths',
#   'time delay compensation',
#   'train-bridge coupling system',
#   'openfresco',
#   'opensees',
#   'seismic response',
#   'substructure scheme',
#   'underground structures',
#   'virtual hybrid simulation',
#   'elastomeric adhesives',
#   'fatigue analysis',
#   'roof-to-wall connection',
#   'wind loads',
#   'architectural design',
#   'building information modeling (bim) interoperability',
#   'geometric signature',
#   'material signature',
#   'structural analysis',
#   'delay compensation',
#   'distributed real-time hybrid testing',
#   'structural seismic response',
#   'time delay',
#   'time-dependent behavior',
#   'boundary coordination',
#   'delay compensation',
#   'numerical substructure',
#   'real-time hybrid test',
#   'shaking table substructure test',
#   'damage detection',
#   'modal properties',
#   'numerical simulations',
#   'structural health monitoring',
#   'wavelet transform',
#   'coupling',
#   'nonstructural component',
#   'offline iteration',
#   'response spectra reproduction',
#   'shaking table test',
#   'benchmark problem',
#   'delay compensation',
#   'improved adaptive polynomial-based forward prediction',
#   'real time hybrid simulation',
#   'sliding mode control',
#   'ltr',
#   'real-time hybrid simulation',
#   'rlqg',
#   'robustness',
#   'uncertainties',
#   'damage detection',
#   'dome structure',
#   'fractal geometry',
#   'uniform load surface',
#   'damage measure',
#   'fragility curves',
#   'incremental dynamic analysis',
#   'limit states',
#   'subway station structure',
#   'fragility assessment',
#   'high-rise',
#   'incremental dynamic analysis',
#   'rc buildings',
#   'seismic performance',
#   'shear wall',
#   'hybrid simulation controller',
#   'incremental development approach',
#   'seismic retrofits',
#   'woodframe buildings',
#   'collapse',
#   'fema p-807',
#   'full-scale test',
#   'hybrid testing',
#   'retrofit',
#   'soft-story',
#   'woodframe',
#   'hybrid simulation',
#   'large-scale testing',
#   'opensees',
#   'reinforced concrete',
#   'structural failure',
#   'fema p-807',
#   'full-scale test',
#   'hybrid testing',
#   'retrofit',
#   'soft-story',
#   'wood-frame',
#   'energy dissipation',
#   'real-time hybrid simulation',
#   'time delay compensation',
#   'viscous damper',
#   'wood shear wall',
#   'hybrid testing',
#   'seismic experimentation',
#   'substructuring',
#   'testing system',
#   'collapse',
#   'earthquake',
#   'fema p-807',
#   'risk reduction',
#   'seismic retrofit',
#   'soft-story',
#   'woodframe',
#   'hybrid simulation',
#   'seismic retrofit',
#   'soft-story',
#   'timber',
#   'weak-story',
#   'wood-frame',
#   'fema p-807',
#   'hybrid test',
#   'knee-brace',
#   'reversed cyclic',
#   'seismic retrofit',
#   'soft-story',
#   'timber',
#   'wcte 2014',
#   'weak-story',
#   'wood-frame',
#   'damper',
#   'full-scale test',
#   'hybrid test',
#   'retrofit',
#   'shape memory alloy',
#   'soft-story',
#   'woodframe',
#   'hybrid simulation',
#   'integration algorithm',
#   'nees projects',
#   'real-time compensation',
#   'seismic experimentation',
#   'collapse',
#   'light-frame wood',
#   'performance-based retrofit',
#   'soft-story building',
#   'decision making',
#   'genetic algorithms',
#   'hospital',
#   'seismic engineering',
#   'controller platform',
#   'general formulation',
#   'hybrid simulation',
#   'real-time testing',
#   'substructure testing',
#   'dynamic tests',
#   'experimentation',
#   'general formulation',
#   'hybrid methods',
#   'pseudodynamic method',
#   'advanced seismic testing',
#   'dynamic force control',
#   'hydraulic actuators',
#   'natural velocity feedback',
#   'smith predictor',
#   'concrete canstruction',
#   'flat concrete slabs',
#   'punching shear',
#   'reinforced concrete',
#   'structural design',
#   'elastomeric adhesives',
#   'fatigue analysis',
#   'roof-to-wall connection',
#   'wind loads',
#   'damage detection',
#   'modal properties',
#   'numerical simulations',
#   'structural health monitoring',
#   'wavelet transform',
#   'fragility assessment',
#   'high-rise',
#   'incremental dynamic analysis',
#   'rc buildings',
#   'seismic performance',
#   'shear wall',
#   'decision making',
#   'genetic algorithms',
#   'hospital',
#   'seismic engineering'],
#  '8354044800': ['artificial intelligence trustworthiness',
#   'curricular initiative',
#   'education',
#   'experiential learning',
#   'information technology',
#   'it education',
#   'benchmark',
#   'covid-19',
#   'dataset',
#   'deep learning',
#   'fake news',
#   'misinformation',
#   'twitter',
#   'helium',
#   'hitl',
#   'internet of things',
#   'lorawan',
#   'fitness sharing',
#   'genetic algorithm',
#   'parallel algorithm',
#   'parallel genetic algorithm',
#   'resource sharing',
#   'user interface',
#   'phrase sense disambiguation',
#   'research trend analysis',
#   'text mining',
#   'active learning',
#   'artificial intelligence readiness',
#   'computing education',
#   'experiential learning',
#   'stem education',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'experiential learning',
#   'it education',
#   'computational intelligence',
#   'deep learning',
#   'human-like intelligence',
#   'language modeling',
#   'machine learning',
#   'natural language processing',
#   'neural networks',
#   'transfer learning',
#   'transformers',
#   'ai applications',
#   'deep learning applications',
#   'language modeling',
#   'machine commonsense reasoning',
#   'machine learning models',
#   'natural language processing',
#   'neural networks',
#   'transfer learning',
#   'transformers',
#   '21st century skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'stem',
#   '21st skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'hands-on activities',
#   'stem education',
#   'automatic redundancy reduction',
#   'compiler',
#   'dag',
#   'dependence analysis',
#   'machine learning',
#   'parallel processing',
#   'theory of computation',
#   'analysis toolkit',
#   'big data',
#   'high performance computing',
#   'risky decision making',
#   'saas',
#   'active data bundles',
#   'fog',
#   'iot',
#   'policy',
#   'policy enforcement',
#   'big data analytics',
#   'machine learning (ml)',
#   'smart buildings',
#   'smart homes',
#   'the internet of things (iot)',
#   'big data',
#   'crux-tide',
#   'indexing',
#   'parallel processing',
#   'proteomics',
#   'shared memory',
#   'big data',
#   'deep learning',
#   'machine learning',
#   'ms/ms filters',
#   'protein search engine',
#   'searching space optimization',
#   'shallow learning',
#   'cloud computing',
#   'data reduction',
#   'deep learning',
#   'network traffic',
#   'protein search engine',
#   'searching space reduction',
#   'acm ccs',
#   'domain',
#   'k-means',
#   'ontology',
#   'wup similarity',
#   'deep machine learning',
#   'parameter optimization',
#   'particle swarm optimization',
#   'smart building services',
#   'clustering',
#   'cuda',
#   'ensemble clustering',
#   'machine learning',
#   'risky decision making',
#   'arima',
#   'iot services',
#   'lstm',
#   'machine learning',
#   'smart buildings',
#   'smart homes',
#   'time series',
#   'wi-fi networks',
#   'big data',
#   'data flood',
#   'data reduction',
#   'ground truth',
#   'high throughput mass spectrometry',
#   'peak sampling',
#   'proteomics',
#   'comet',
#   'optimization',
#   'particle swarm',
#   'proteomics',
#   'search engine',
#   'tolerance window',
#   'artificial immune system',
#   'internet traffic classification',
#   'machine learning',
#   'multi-class classification',
#   'ensemble clustering application',
#   'machine learning',
#   'mpi',
#   'multi-objective optimization',
#   'parallel distributed processing',
#   'risky decision making',
#   'big data',
#   'crux tide',
#   'indexing',
#   'parallel processing',
#   'proteomics',
#   'shared memory',
#   'bitalino',
#   'bluetooth',
#   'fourier transforms',
#   'median frequency',
#   'muscle fatigue',
#   'surface electromyography',
#   'naïve bayes classifier',
#   'nlp',
#   'preposition disambiguation',
#   'supervised classification',
#   'arima',
#   'arima-garch',
#   'garch',
#   'predictive analysis',
#   'sarima',
#   'traffic',
#   'ad hoc networks',
#   'oppnets',
#   'opportunistic networks',
#   'specialized ad hoc networks',
#   'application-oriented networks',
#   'integer linear programming problem',
#   'lagrangean relaxation',
#   'managing network resources and services',
#   'opportunistic networks',
#   'optimization problem',
#   'service location and planning problem',
#   'application oriented networks',
#   'lagrangean relaxation',
#   'opportunistic networks',
#   'service location planning problem',
#   'classification',
#   'maximum aposterior classifier',
#   'power consumption analysis',
#   'wireless sensor networks',
#   'distance estimates',
#   'error bound',
#   'localization',
#   'position',
#   'sensor network',
#   'cisco application oriented networks',
#   'integer linear program',
#   'mobile wireless computing',
#   'networks',
#   'service location problem',
#   'ad hoc networks',
#   'collaborative communication',
#   'collaborative computing',
#   'opportunistic networks',
#   'pervasive computing',
#   'classification',
#   'collaborative processing',
#   'lu decomposition',
#   'sensor networks',
#   'classification',
#   'collaborative processing',
#   'jacobi iterations',
#   'sensor networks',
#   'classification',
#   'collaborative processing',
#   'lu decomposition',
#   'sensor networks',
#   'anomaly intrusion',
#   'cdma',
#   'dsdv',
#   'dsr',
#   'fhss',
#   'tdma',
#   'wireless sensor network',
#   'evolution strategies',
#   'localization',
#   'sensor networks',
#   'collaborative signal processing and classification',
#   'fusion',
#   'energy efficient',
#   'fft',
#   'load balancing',
#   'power efficient',
#   'sensor networks',
#   'signal processing',
#   'algorithm porting',
#   'dilation',
#   'embeddings',
#   'emulation',
#   'expansion',
#   'hypercubes',
#   'interconnection networks',
#   'trees',
#   'security protocols',
#   'wireless sensor networks (wsn)',
#   'cluster computing',
#   'high performance computing',
#   'integration software library',
#   'load balancing',
#   'task allocation',
#   'evolution strategies',
#   'preventive maintenance',
#   'workforce scheduling',
#   'adaptive multivariate integration',
#   'asymptotic error',
#   'load balanced',
#   'embeddings',
#   'evolutionary strategies',
#   'hypercubes',
#   'task assignments',
#   'algorithms',
#   'graph embeddings',
#   'hypercube',
#   'incomplete hypercubes',
#   'binary tree networks',
#   'congestion',
#   'dilation',
#   'graph embeddings',
#   'load',
#   'lower bounds',
#   'area and volume',
#   'binary tree',
#   'graph layout',
#   'cluster computing',
#   'high performance computing',
#   'integration software library',
#   'load balancing',
#   'task allocation',
#   'adaptive multivariate integration',
#   'asymptotic error',
#   'load balanced',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'education',
#   'experiential learning',
#   'information technology',
#   'it education',
#   'active learning',
#   'artificial intelligence readiness',
#   'computing education',
#   'experiential learning',
#   'stem education',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'experiential learning',
#   'it education',
#   'computational intelligence',
#   'deep learning',
#   'human-like intelligence',
#   'language modeling',
#   'machine learning',
#   'natural language processing',
#   'neural networks',
#   'transfer learning',
#   'transformers',
#   'ai applications',
#   'deep learning applications',
#   'language modeling',
#   'machine commonsense reasoning',
#   'machine learning models',
#   'natural language processing',
#   'neural networks',
#   'transfer learning',
#   'transformers',
#   '21st century skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'stem',
#   '21st skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'hands-on activities',
#   'stem education',
#   'active data bundles',
#   'fog',
#   'iot',
#   'policy',
#   'policy enforcement',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'education',
#   'experiential learning',
#   'information technology',
#   'it education',
#   'active learning',
#   'artificial intelligence readiness',
#   'computing education',
#   'experiential learning',
#   'stem education',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'experiential learning',
#   'it education',
#   '21st century skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'stem',
#   '21st skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'hands-on activities',
#   'stem education',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'education',
#   'experiential learning',
#   'information technology',
#   'it education',
#   'active learning',
#   'artificial intelligence readiness',
#   'computing education',
#   'experiential learning',
#   'stem education',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'experiential learning',
#   'it education',
#   'computational intelligence',
#   'deep learning',
#   'human-like intelligence',
#   'language modeling',
#   'machine learning',
#   'natural language processing',
#   'neural networks',
#   'transfer learning',
#   'transformers',
#   'ai applications',
#   'deep learning applications',
#   'language modeling',
#   'machine commonsense reasoning',
#   'machine learning models',
#   'natural language processing',
#   'neural networks',
#   'transfer learning',
#   'transformers',
#   '21st century skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'stem',
#   '21st skills development',
#   'artificial intelligence',
#   'experiential learning',
#   'hands-on activities',
#   'stem education',
#   'big data analytics',
#   'machine learning (ml)',
#   'smart buildings',
#   'smart homes',
#   'the internet of things (iot)',
#   'big data analytics',
#   'machine learning (ml)',
#   'smart buildings',
#   'smart homes',
#   'the internet of things (iot)',
#   'deep machine learning',
#   'parameter optimization',
#   'particle swarm optimization',
#   'smart building services',
#   'arima',
#   'iot services',
#   'lstm',
#   'machine learning',
#   'smart buildings',
#   'smart homes',
#   'time series',
#   'wi-fi networks',
#   'artificial immune system',
#   'internet traffic classification',
#   'machine learning',
#   'multi-class classification',
#   'application-oriented networks',
#   'integer linear programming problem',
#   'lagrangean relaxation',
#   'managing network resources and services',
#   'opportunistic networks',
#   'optimization problem',
#   'service location and planning problem',
#   'application oriented networks',
#   'lagrangean relaxation',
#   'opportunistic networks',
#   'service location planning problem',
#   'cisco application oriented networks',
#   'integer linear program',
#   'mobile wireless computing',
#   'networks',
#   'service location problem',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'education',
#   'experiential learning',
#   'information technology',
#   'it education',
#   'active learning',
#   'artificial intelligence readiness',
#   'computing education',
#   'experiential learning',
#   'stem education',
#   'artificial intelligence trustworthiness',
#   'curricular initiative',
#   'experiential learning',
#   'it education',
#   'big data',
#   'deep learning',
#   'machine learning',
#   'ms/ms filters',
#   'protein search engine',
#   'searching space optimization',
#   'shallow learning',
#   'comet',
#   'optimization',
#   'particle swarm',
#   'proteomics',
#   'search engine',
#   'tolerance window'],
#  '8100859100': ['devotional artifacts',
#   'fort st. joseph',
#   'french missions',
#   'indian converts',
#   'jesuits',
#   'missionaries',
#   'new france',
#   'religiosity'],
#  '7801695159': ['children of incarcerated parents',
#   'parenting programs',
#   'women prisoners'],
#  '7801513442': ['assessment',
#   'grandparent-headed families',
#   'parent education',
#   'programming',
#   'service delivery',
#   'adolescent sexual offender',
#   'paraphilia',
#   'pedophilia',
#   'assessment',
#   'grandparent-headed families',
#   'parent education',
#   'programming',
#   'service delivery',
#   'adolescent sexual offender',
#   'paraphilia',
#   'pedophilia',
#   'adolescent sexual offender',
#   'paraphilia',
#   'pedophilia'],
#  '7801395146': ['cluster computing',
#   'high performance computing',
#   'integration software library',
#   'load balancing',
#   'task allocation',
#   'adaptive multivariate integration',
#   'asymptotic error',
#   'load balanced',
#   'dimensional regularization',
#   'feynman loop diagrams',
#   'gpus',
# ...
#   'ionic liquids',
#   'sustainable flooding',
#   'alcohols',
#   'glymes',
#   'hydrogen bonding',
#   'liquid mixtures',
#   'molecular simulation',
#   'thermophysics',
#   'carbon dioxide',
#   'intermolecular forces',
#   'molecular simulation',
#   'porous liquids',
#   'covid-19',
#   'deep eutectic solvents',
#   'l-arginine',
#   'molecular simulations',
#   'nitric oxide',
#   'co  activation 2',
#   'mos  monolayers 2',
#   'single atom catalysts',
#   'transition metal adsorption',
#   'absorption',
#   'carbon dioxide capture',
#   'deep eutectic solvents',
#   'density functional theory',
#   'hydrogen bond',
#   'alkanediols',
#   'hydrogen bonding',
#   'liquid mixtures',
#   'molecular modelling',
#   'pyrrolidone',
#   'thermophysics',
#   'composite polymer',
#   'ionic liquids',
#   'membrane separation',
#   'propane/propylene separation',
#   'gas hydrates',
#   'hydrate inhibitors',
#   'ionic liquids',
#   'methane hydrates',
#   'synergents',
#   'carbon nanomaterials',
#   'graphene',
#   'lipids',
#   'membranes',
#   'molecular dynamics',
#   'alkylimidazolium ionic liquids',
#   'mixture',
#   'molecular simulation',
#   'molecular solvents',
#   'thermophysics',
#   'deep eutectic solvents',
#   'natural products',
#   'physicochemical properties',
#   'deep eutectic solvents',
#   'density functional theory',
#   'gas capture',
#   'so 2',
#   'acid-gas capture',
#   'boron nitride',
#   'molecular simulations',
#   'nanomaterials',
#   'deep eutectic solvents',
#   'hydrogen bonding',
#   'interfaces',
#   'mixtures',
#   'nanomaterials',
#   'covalent organic polymers',
#   'density functional theory',
#   'gas adsorption',
#   'porous materials',
#   'choline chloride',
#   ' viscosity',
#   'deep eutectic solvents',
#   'imidazolium',
#   'ionic liquids',
#   'rheology',
#   'viscoelastic',
#   'gas separation',
#   'ionic liquid',
#   'molecular dynamics',
#   'deep eutectic solvents',
#   'intermolecular forces',
#   'methanol',
#   'mixtures',
#   'thermophysics',
#   'alkylimidazolium ionic liquids',
#   'ether',
#   'mixtures',
#   'molecular simulation',
#   'thermophysics',
#   'flow assurance',
#   'gas hydrates',
#   'inhibitors',
#   'protic ionic liquids',
#   'dft',
#   'gas capture',
#   'gas storage',
#   'porous polymers',
#   'dft',
#   'hydrogen bonding',
#   'imidazolium',
#   'ionic liquid',
#   'mixtures',
#   'molecular solvent',
#   'raman',
#   'ch -n -co 4 2 2',
#   'gases adsorption',
#   'high pressure',
#   'zeolites',
#   'deep eutectic solvents',
#   'gas solubility',
#   'natural products',
#   'rheology',
#   'atom in a molecule (aim)',
#   'benzimidazole-linked polymers',
#   'density functional theory (dft)',
#   'gas capture',
#   'gas storage',
#   'hydrogen bonding',
#   'ionic liquid mixtures',
#   'molecular solvents',
#   'simulation',
#   'water',
#   'carbon dioxide',
#   'deep eutectic solvents',
#   'dft',
#   'gas solubility',
#   'ionic liquids',
#   'rheology',
#   'bioenergy production system',
#   'computer-aided molecular design',
#   'decision-making tool',
#   'disjunctive programming',
#   'input-output modeling',
#   'external electric fields',
#   'ionic liquids',
#   'mixtures',
#   'molecular dynamics',
#   'vacuum interfaces',
#   'water',
#   'carbon capture',
#   'deep eutectic solvents',
#   'gas solubility',
#   'rheology',
#   'thermodynamic properties',
#   'amino acids',
#   'hydrates',
#   'methane gas',
#   'synergents',
#   'hydrates',
#   'ionic liquids',
#   'natural gas mixture',
#   'synergents',
#   'amino acids',
#   'flow assurance',
#   'gas hydrates',
#   'kinetic inhibitors',
#   'synergetic compounds',
#   'thermodynamic inhibitors',
#   'flow assurance',
#   'gas hydrate',
#   'hydrate blockage removal',
#   'meg/methanol mixture',
#   'flow assurance',
#   'gas hydrates',
#   'ionic liquids',
#   'phase behaviour',
#   'thermodynamic inhibitors',
#   'flow assurance',
#   'gas hydrate',
#   'hydrate blockage removal',
#   'meg',
#   'methanol',
#   'dimensional analysis',
#   'gas transmission and storage',
#   'hydrate production',
#   'stirring',
#   'acid gases',
#   'aminoacid',
#   'dft',
#   'ionic liquids',
#   'mixtures',
#   'molecular dynamics',
#   'water',
#   'co  separation membranes 2',
#   'mixed matrix membranes',
#   'permeability',
#   'polymer blends',
#   'polymeric membranes',
#   'selectivity',
#   'supported ionic liquid membranes',
#   'co  separation 2',
#   'dense membrane',
#   'ionic liquid',
#   'polysulfone',
#   'supported ionic liquid membranes',
#   'group contribution',
#   'property clustering',
#   'property integration',
#   'ternary diagram',
#   'co  capture 2',
#   'covalent organic polymers',
#   'high-pressure capture',
#   'porous adsorbents',
#   'acid gases',
#   'amino acid',
#   'flue gas',
#   'interface',
#   'ionic liquids',
#   'molecular dynamics',
#   'vacuum',
#   'carbon capture',
#   'group contribution method',
#   'ionic liquids',
#   'molecular design',
#   'property clustering technique',
#   'property integration',
#   'ternary diagram',
#   'co 2',
#   'gas separation',
#   'high pressure',
#   'polybenzimidazole',
#   'aminoacid ions',
#   'intermolecular forces',
#   'ionic liquids',
#   'molecular dynamics',
#   'co  capture 2',
#   'high pressure',
#   'modified sba-15',
#   'solid sorbent',
#   'atomic charges',
#   'deep eutectic solvents',
#   'force field parameterization',
#   'molecular dynamics',
#   'co2 capture',
#   'deep eutectic solvents',
#   'dft',
#   'ionic liquids',
#   'carbon capture and storage',
#   'group contribution method',
#   'ionic liquids',
#   'unifac model',
#   'adsorption',
#   'dft',
#   'flavonols',
#   'graphene',
#   'acid gas capture',
#   'choline',
#   'cosmo-rs',
#   'dft',
#   'ionic liquid',
#   'phosphate',
#   'group contribution',
#   'ionic liquid design',
#   'property clustering',
#   'density',
#   'equation of state',
#   'natural gas',
#   'phase envelope',
#   'phase equilibrium',
#   'chemical engineering core curriculum',
#   'fluid mechanics',
#   'inquiry guided learning',
#   'teaching chemical engineering education',
#   'dielectric relaxation',
#   'green solvents',
#   'infrared',
#   'lactate',
#   'spectroscopy',
#   'thermophysics',
#   'water mixtures',
#   'dft and uniquac calculations',
#   'ionic liquid',
#   'olefin/paraffin separation',
#   'spectroscopy',
#   'density functional theory',
#   'hydrates',
#   'natural gas',
#   'quantumchemistry',
#   'atoms-in-molecules',
#   'carbon dioxide',
#   'ionic liquids',
#   'natural bond orbitals',
#   'piperazine',
#   'quantum chemistry',
#   'carbon dioxide',
#   'high-pressure',
#   'imidazolium',
#   'ionic liquids',
#   'molecular dynamics',
#   'solubility',
#   'adsorption',
#   'carbon dioxide',
#   'porous polymers',
#   'thermal stability',
#   'basolite',
#   'co  adsorption 2',
#   'dft',
#   'high-pressure ftir',
#   'mof',
#   '1',
#   '2-alkanediols',
#   'density',
#   'high pressure',
#   'internal pressure',
#   'isobaric thermal expansivity',
#   'isothermal compressibility',
#   'pc-saft',
#   'adsorption',
#   'carbon dioxide',
#   'high pressure',
#   'monte carlo',
#   'prussian blue analogues',
#   'intermolecular forces',
#   'ionic liquids',
#   'molecular dynamics',
#   'thermodynamics',
#   'water chemistry',
#   'density',
#   'equation of state',
#   'high pressure',
#   'multicomponent mixtures',
#   'natural gas',
#   'binary and multicomponent mixtures',
#   'correlation',
#   'eyring theory',
#   'kinematic viscosity',
#   'mcallister equation',
#   'co   absorption 2',
#   'hydroxylammonium ionic liquids',
#   'molecular dynamics',
#   'water',
#   '1-alkanols',
#   'density',
#   'high pressure',
#   'internal pressure',
#   'isobaric thermal expansivity',
#   'isothermal compressibility',
#   'densimeter',
#   'force transmission error',
#   'high pressure',
#   'magnetic suspension coupling',
#   'densities',
#   'isochoric apparatus',
#   'magnetic suspension densimeter',
#   'natural gas',
#   'phase loops',
#   'densities',
#   'equations of state',
#   'mixtures',
#   'natural gas',
#   'phase loops'],
#  '12771755200': ['cardiac arrest',
#   'cardiopulmonary resuscitation',
#   'cpr',
#   'cpr refreshers',
#   'prehospital emergency care',
#   'cardiac arrest',
#   'cardiopulmonary resuscitation',
#   'cpr',
#   'cpr refreshers',
#   'prehospital emergency care',
#   'cardiac arrest',
#   'cardiopulmonary resuscitation',
#   'cpr',
#   'cpr refreshers',
#   'prehospital emergency care',
#   'children; wic; educational resource; health care; digital health; nutrition; web-based education; web-based nutrition; pediatric; parenting; dashboard',
#   'infants',
#   'keywords covid-19; user engagement; infodemic; women',
#   'attitudes',
#   'behaviors',
#   'covid-19',
#   'knowledge',
#   'masks',
#   'vaccine hesitancy',
#   'engagement',
#   'internet',
#   'online video',
#   'wic',
#   'behavior change',
#   'internet interventions',
#   'apps',
#   'facebook',
#   'nutrition education',
#   'online',
#   'wic',
#   'cardiac arrest',
#   'cardiopulmonary resuscitation',
#   'cpr',
#   'cpr refreshers',
#   'prehospital emergency care',
#   'internet',
#   'obesity',
#   'online',
#   'weight loss',
#   'child nutrition',
#   'internet',
#   'nutrition',
#   'wic'],
#  '12142293800': ['clinical decision making',
#   'costovertebral and costotransverse joints',
#   'differential diagnosis',
#   'joint mobilization',
#   'manual therapy',
#   'rib',
#   'trigger point',
#   'upper thoracic pain',
#   'amenorrhea',
#   'bone mineral density',
#   'stress fracture'],
#  '11739533900': ['infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'early childhood',
#   'home visiting',
#   'provider-client alliance',
#   'visitas a casa',
#   'engagement in services',
#   'home visiting services',
#   'postpartum',
#   'pregnancy',
#   'children',
#   'exposure',
#   'infants',
#   'intimate partner violence',
#   'mothers',
#   'perinatal',
#   'qualitative',
#   'trauma',
#   'intimate partner violence',
#   'perinatal health care',
#   'depression prevalence',
#   'maternal depression',
#   'onset',
#   'intimate partner violence',
#   'postpartum depression',
#   'poverty',
#   'socioeconomic status',
#   'infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'health care barriers',
#   'intimate partner violence',
#   "women and children's health",
#   'intimate partner violence',
#   'postpartum depression',
#   'poverty',
#   'socioeconomic status',
#   'depression prevalence',
#   'maternal depression',
#   'onset',
#   'disparities',
#   'mixed-methods',
#   ' postpartum care',
#   'postnatal care',
#   'birth outcomes',
#   'income',
#   'low birthweight',
#   'neighborhood racial density',
#   'race',
#   'racial congruity',
#   'racial disparity',
#   'socioeconomic status',
#   'united states',
#   'informational support',
#   'perinatal health care',
#   'qualitative research',
#   'intimate partner violence',
#   'perinatal health care',
#   'health care barriers',
#   'intimate partner violence',
#   "women and children's health",
#   'infant mortality',
#   'maternal depression',
#   'maternal psychosocial risk factors',
#   'maternal stress',
#   'safe sleep practices',
#   'disparities',
#   'mixed-methods',
#   ' postpartum care',
#   'postnatal care',
#   'informational support',
#   'perinatal health care',
#   'qualitative research',
#   'children',
#   'exposure',
#   'infants',
#   'intimate partner violence',
#   'mothers',
#   'perinatal',
#   'qualitative',
#   'trauma',
#   'early childhood',
#   'home visiting',
#   'provider-client alliance',
#   'visitas a casa',
#   'disparities',
#   'health outcomes',
#   'income',
#   'infant mortality',
#   'multiracial',
#   'engagement in services',
#   'home visiting services',
#   'postpartum',
#   'pregnancy',
#   'intimate partner violence',
#   'perinatal health care',
#   'health care barriers',
#   'intimate partner violence',
#   "women and children's health",
#   'kitagawa analysis',
#   'perinatal periods of risk',
#   'racial disparities',
#   'socioeconomic disparities',
#   'birth outcomes',
#   'income',
#   'low birthweight',
#   'neighborhood racial density',
#   'race',
#   'racial congruity',
#   'racial disparity',
#   'socioeconomic status',
#   'united states',
#   'depression prevalence',
#   'maternal depression',
#   'onset',
#   'intimate partner violence',
#   'postpartum depression',
#   'poverty',
#   'socioeconomic status',
#   'displacement',
#   'domestic violence',
#   'prosecution',
#   'resources',
#   'intimate partner violence',
#   'reform court procedures',
#   'socio-ecological model',
#   'intimate partner violence',
#   'prosecution',
#   'safety',
#   'hospitalization rates.',
#   'intimate partner violence',
#   'ipv perpetrators',
#   'ipv victims',
#   'battered women',
#   'domestic violence',
#   'legal intervention',
#   'emergency departments',
#   'health care screening',
#   'interventions',
#   'intimate partner violence',
#   'police incidents',
#   'risk identification',
#   'children',
#   'help seeking',
#   'intimate partner violence',
#   'personal protection order',
#   'prosecution',
#   'intimate partner violence',
#   'prosecution',
#   'victim participation',
#   'fetal mortality',
#   'infant mortality',
#   'maternal risk',
#   'barriers to help-seeking',
#   'child exposure',
#   'decision-making',
#   'domestic violence',
#   'intimate partner violence'],
#  '11439666300': ['interaction field modeling',
#   'mini-uav',
#   'swarm',
#   'interaction field modeling',
#   'mini-uav',
#   'swarm',
#   'flight dynamics',
#   'flight simulation',
#   'flying wing',
#   'uav',
#   'winglet',
#   'analytical modeling',
#   'autonomous underwater vehicle (auv)',
#   'control design',
#   'flight dynamics',
#   'nonlinear simulation'],
#  '57200182807': [],
#  '10639017100': ['accelerated earnings',
#   'aggressive revenue recognition',
#   'expense accruals',
#   'method-shifting',
#   'r&amp;d',
#   'revenue accruals',
#   'activity-based costing',
#   'data envelopment analysis',
#   'mathematical programming',
#   'performance evaluation',
#   'statistics',
#   'distribution theory',
#   'financial modeling',
#   'statistical techniques'],
#  '10340785600': ['chemistry',
#   'earth science',
#   'faculty development',
#   'grading',
#   'physics',
#   'quantitative problem solving',
#   'advanced technological education centers',
#   'college-program relationship',
#   'core competencies',
#   'program effectiveness',
#   'program outcomes',
#   'authentic inquiry',
#   'biogeochemical cycles',
#   'eutrophication',
#   'limnology',
#   'teaching biogeochemistry',
#   'dispositional thinking',
#   'expertise',
#   'gis',
#   'problem solving',
#   'spatial analysis',
#   'aerial photography',
#   'field research',
#   'geological sciences',
#   'navigation',
#   'topographic maps',
#   'cognitive ability',
#   'expertise',
#   'individual differences',
#   'scientific problem solving',
#   'expert vs. novice',
#   'field mapping',
#   'geologic expertise',
#   'spatial signatures',
#   'case study',
#   'fieldwork',
#   'students’ skills development',
#   'teamwork',
#   'environmental geoscience',
#   'input-process-output model',
#   'online focus group',
#   'teamwork',
#   'workforce skills',
#   '3d printing',
#   'introductory course',
#   'pilot study',
#   'topography teaching',
#   'climate change',
#   'ozone depletion-climate change assessment',
#   'ozone layer',
#   'atmospheric science',
#   'meteorology',
#   'oceanography',
#   'spatial thinking',
#   'experiential education',
#   'field-based learning',
#   'geologic mapping',
#   'qualitative research',
#   'situated learning theory',
#   'climate change',
#   'environmental education',
#   'media',
#   'survey',
#   'meteorology education',
#   'practitioner wisdom',
#   'spatial thinking',
#   'geoscience education research',
#   'graduate preparation',
#   'k-12',
#   'motivation',
#   'dispositional thinking',
#   'expertise',
#   'gis',
#   'problem solving',
#   'spatial analysis',
#   'aerial photography',
#   'field research',
#   'geological sciences',
#   'navigation',
#   'topographic maps',
#   'chemistry',
#   'earth science',
#   'faculty development',
#   'grading',
#   'physics',
#   'quantitative problem solving',
#   'authentic inquiry',
#   'biogeochemical cycles',
#   'eutrophication',
#   'limnology',
#   'teaching biogeochemistry',
#   'cognitive ability',
#   'expertise',
#   'individual differences',
#   'scientific problem solving',
#   'expert vs. novice',
#   'field mapping',
#   'geologic expertise',
#   'spatial signatures',
#   'advanced technological education centers',
#   'college-program relationship',
#   'core competencies',
#   'program effectiveness',
#   'program outcomes',
#   'columbia river basalt dike',
#   'crustal melting',
#   'dehydration-melting',
#   'thermal model',
#   'tonalite-granodiorite']}

# %% [markdown]
# Replacing ScopusID as the main identifier within the dictionary with researcherID, a unique ID assigned to researchers by the creator outside the script. This new dictionary also creates an identifier with a blank list for those who might not have scholarship indexed by Scopus or might not have author keywords associated with their articles within Scopus.

# %%
#creating researcherID:Scopuskeyword dictionary outside of loop
researkey_dict = dict({})

#looping through each researcherID:scopusID(s) list
with open(researcher_scopus, 'r', encoding="utf8") as f: #opening file
    uniqueID_scopusID = f.readlines() #reading in entire file as string
    for line in uniqueID_scopusID: #for each researcherID and ScopusID(s) pairing within line
        temp_list = line.rstrip('\n').replace(';',':').split(':') #split line of string into list
        uniqueID = temp_list[0] #take the first value in list (researcherID) and put it into a temporary list
        
        if temp_list[1] != '': #if there are ScopusIDs associated with the researcherID
            scopusIDs = temp_list[1:] #put the rest of the list values (ScopusIDs) into a temporary list
            
            for ID in scopusIDs: #start looping through ScopusIDs in list of all researcher ScopusIDs
                if ID in aukey_dict: #check if ID is in ScopusID:authorkeyword dictionary
                    if not uniqueID in researkey_dict: #if researcherID is not in researcherID:Scopuskeyword dictionary
                        if type(aukey_dict[ID]) is float: #check if there are no author keywords associated with ScopusID (values in dictionary are nan (float))
                            researkey_dict[uniqueID] = [] #append blank list as value to the researcherID key in dictionary
                        else: #if there are author keywords associated with ScopusID
                            researkey_dict[uniqueID] = aukey_dict[ID] #add those keywords as values to the researcherID key in dictionary
                    else: #if researcherID is already in researcherID:Scopuskeyword dictionary
                        if type(aukey_dict[ID]) is float: #check if there are no author keywords associated with ScopusID (values in dictionary are nan (float))
                            pass #if there are no author keywords, do nothing
                        else: #if there are author keywords associated with ScopusID
                            researkey_dict[uniqueID].extend(aukey_dict[ID]) #add those author keywords to values in the researcherID key in dictionary
                else: #if ID is not in ScopusID:authorkeyword dictionary
                    if not uniqueID in researkey_dict: #and if researcherID is already not in researcherID:Scopuskeyword dictionary
                        researkey_dict[uniqueID] = [] #add the researcherID to dictionary with blank list as value
                        
        else: #if there are no ScopusIDs associated with the researcherID
            researkey_dict[uniqueID] = [] #add the researcherID to dictionary with blank list as value

# %% [markdown]
# Adding additional keywords from sources outside of Scopus, scraped from ORCiD profiles, directory researcher keywords or biographies, landing pages for departmental research topics, and from the Faculty Annual Reporting System (FARS), to each of the researcherIDs. Deduplicating keywords to include only unique values. Exporting intermediary file that lists all keywords for each researcher (before key-pairs are flipped in the next step).

# %%
with open(researcher_additionalkeywords, 'r', encoding="utf8") as f: #opening file
    uniqueID_keywords = f.readlines() #reading in entire file as string
    for line in uniqueID_keywords: #for each researcherID and keywords pairing within line
        temp_list = line.rstrip('\n').replace('; ',':').split(':') #split line of string into list
        uniqueID = temp_list[0] #take the first value in list (researcherID) and put it into a temporary list
        
        if temp_list[1] != '': #if there are additional keywords associated with the researcherID
            keywords = temp_list[1:] #put the rest of the list values (additional keywords) into a temporary list
            researkey_dict[uniqueID].extend(keywords) #then add these additional keywords to the researcherID:Scopuskeywords dictionary
        researkey_dict[uniqueID] = list(set(researkey_dict[uniqueID])) #dedeplicate the keyword values
        
researkey_dict #preview dictionary to see if additional keywords appended and deduplicated correctly

#creating dataframe from dictionary, where the researcherID is one column and keywords are a second column
researkey_dataframe = pd.DataFrame.from_dict(researkey_dict, orient='index')

#looking up today's date and exporting partial composite dataframe to comma separated value file with utf-8 encoding    
todays_date = date.today()
researkey_dataframe.to_csv(f"{todays_date.isoformat()}_WMUresearcher_keywords_check.csv", index=True, encoding='utf-8-sig')

# %% [markdown]
# Flipping key (researcherID) and values (research keywords) so that researchers are aggregated under shared keywords (keyword:researcher(s))

# %%
#creating keyword:researcherID(s) dictionary outside of loop
keyresear_dict = dict({})

#looping through each entry within the researcherID:keyword dictionary
for uniqueID, keywords in researkey_dict.items():
    for keyword in keywords: #for each individual keyword within the keyword list
        if keyword in keyresear_dict: #check if the keyword is already in the keyword:researcherID(s) dictionary
            keyresear_dict[keyword].append(uniqueID) #if the keyword exists, add researcherID to it
        else: #if the keyword does not already exist within the dictionary
            keyresear_dict[keyword] = [uniqueID] #create a new keyword key entry and add affiliated researcherID as value

#checking to see if multiple researcherIDs added correctly to keyword
for keyword, IDs in keyresear_dict.items():
    if len(IDs) > 1: #only selecting keywords that have more than one associated researcherID
        print(keyword, IDs)
# Out:
# covid-19 ['W0001', 'W0179', 'W0215', 'W0216', 'W0221', 'W0222', 'W0242', 'W0248', 'W0249', 'W0274', 'W0342', 'W0343', 'W0349', 'W0350', 'W0713', 'W0740', 'W0823', 'W0831', 'W0891', 'W1012', 'W1013', 'W1034', 'W1040', 'W1085', 'W1093', 'W1102', 'W1124', 'W1167', 'W1171', 'W1336', 'W1343', 'W1364', 'W1423', 'W1427', 'W1429', 'W1446', 'W1464', 'W1479', 'W1505', 'W1510', 'W1512', 'W1514', 'W1520']
# financial distress ['W0001', 'W0506']
# auditing ['W0001', 'W0163', 'W0790']
# corporate governance ['W0001', 'W0003', 'W0014', 'W0485', 'W0494', 'W0500']
# financial reporting ['W0001', 'W0003', 'W0790']
# tax avoidance ['W0002', 'W0003']
# emerging markets ['W0003', 'W0310', 'W0818']
# gender equality ['W0003', 'W0999']
# political connections ['W0003', 'W0502', 'W0788', 'W0802']
# culture ['W0003', 'W0234', 'W0312', 'W0317', 'W0687', 'W0707', 'W0733', 'W0794', 'W0812', 'W1111', 'W1182', 'W1185', 'W1321', 'W1491', 'W1515']
# mathematical programming ['W0004', 'W0155', 'W0856']
# statistics ['W0004', 'W0210', 'W0334', 'W1108']
# r&amp;d ['W0004', 'W0294', 'W0299', 'W0306', 'W0791']
# performance evaluation ['W0004', 'W0206', 'W0418']
# data envelopment analysis ['W0004', 'W0206', 'W0211', 'W0294', 'W0299']
# ownership structure ['W0011', 'W0485', 'W0491', 'W0500']
# accrual quality ['W0011', 'W0485', 'W0491']
# agency costs ['W0011', 'W0485', 'W0491']
# earnings response coefficient ['W0011', 'W0485', 'W0491']
# intellectual property ['W0012', 'W1108']
# disclosure ['W0014', 'W0264', 'W1182']
# transparency ['W0014', 'W0335', 'W0518']
# security ['W0018', 'W0154', 'W0164', 'W0236', 'W0242', 'W0243', 'W0244', 'W0248', 'W0256', 'W0826', 'W0923']
# communication systems ['W0018', 'W0232']
# work ['W0018', 'W0719', 'W0949', 'W1121']
# weather ['W0018', 'W0054', 'W0340', 'W1442']
# risk ['W0054', 'W0147', 'W0156', 'W0236', 'W0421', 'W0428', 'W0765', 'W0818', 'W0823', 'W0927', 'W1022', 'W1108', 'W1433']
# dna replication ['W0057', 'W0072', 'W0084']
# mutagenesis ['W0057', 'W0191']
# replication ['W0057', 'W0067', 'W1021', 'W1195']
# human ['W0057', 'W0058', 'W0951', 'W1022', 'W1263', 'W1324', 'W1342', 'W1429', 'W1482']
# csr ['W0057', 'W0831']
# molecular genetics ['W0057', 'W0070', 'W0080', 'W0783']
# aid ['W0057', 'W0058', 'W1393']
# polymerase chain reaction ['W0058', 'W1329']
# salivary gland ['W0058', 'W0059', 'W1393', 'W1446']
# igm ['W0058', 'W1393']
# immunosuppression ['W0058', 'W1393', 'W1514']
# proliferation ['W0058', 'W0062', 'W0063', 'W0072', 'W0084', 'W1337', 'W1341', 'W1518']
# ighv sequencing ['W0058', 'W1393']
# apoptosis ['W0058', 'W0062', 'W0072', 'W0081', 'W1326', 'W1341', 'W1342', 'W1393', 'W1446']
# ccr6 ['W0058', 'W1393']
# immunology ['W0058', 'W0067', 'W1324', 'W1327', 'W1393', 'W1394']
# lipopolysaccharide ['W0058', 'W1511']
# schizophrenia ['W0058', 'W1008', 'W1010', 'W1343', 'W1495', 'W1497']
# antibodies ['W0058', 'W1393', 'W1433', 'W1509']
# cpg ['W0058', 'W0830']
# gene expression ['W0058', 'W0063', 'W1326', 'W1329']
# tolerance ['W0058', 'W1008', 'W1010', 'W1024']
# id3 −/− ['W0058', 'W1393']
# transcription factor ['W0058', 'W0070', 'W1341']
# inflammation ['W0058', 'W0067', 'W0176', 'W1324', 'W1326', 'W1337', 'W1341', 'W1393', 'W1409', 'W1429', 'W1463', 'W1468', 'W1514', 'W1518']
# b lymphocytes ['W0058', 'W1393']
# natural antibodies ['W0058', 'W1393']
# autoimmunity ['W0058', 'W1344', 'W1393', 'W1520']
# activation ['W0058', 'W1016', 'W1393']
# molecular biology ['W0058', 'W0068', 'W1341', 'W1344', 'W1393']
# recombinant viral vectors ['W0058', 'W1393']
# spleen ['W0058', 'W1393', 'W1446', 'W1514']
# acute lung injury ['W0058', 'W1393']
# signaling ['W0058', 'W0504', 'W1393']
# cytokine ['W0058', 'W1491']
# cell cycle ['W0058', 'W0072', 'W0084', 'W1341']
# b-1 ['W0058', 'W1393']
# natural antibody ['W0058', 'W1393']
# lif receptor ['W0058', 'W1393']
# ibd ['W0058', 'W1393']
# cytokines ['W0058', 'W0067', 'W1342', 'W1429', 'W1514']
# lymphoma ['W0058', 'W1514']
# il-10 ['W0058', 'W1393', 'W1518']
# lupus erythematosus ['W0058', 'W1393']
# phenotype ['W0058', 'W1180', 'W1433', 'W1495']
# protein kinases/phosphatases ['W0058', 'W1393']
# case report ['W0058', 'W1455', 'W1460', 'W1480', 'W1512']
# sepsis ['W0058', 'W1211', 'W1393', 'W1394', 'W1514']
# immunomodulation ['W0058', 'W1420']
# b-2 cells ['W0058', 'W1393']
# sialadenitis ['W0058', 'W1393']
# immunoglobulin m ['W0058', 'W1393']
# b-1a cells ['W0058', 'W1393']
# natural igm ['W0058', 'W1393']
# lymphocytes ['W0058', 'W1393']
# autoantibody ['W0058', 'W1393']
# repertoire analysis ['W0058', 'W1393']
# signal transduction ['W0058', 'W0062', 'W0176', 'W1324', 'W1354', 'W1393']
# cell differentiation ['W0058', 'W1393']
# b cell subsets ['W0058', 'W1393']
# aging ['W0058', 'W0078', 'W0081', 'W0082', 'W0092', 'W0095', 'W0187', 'W0312', 'W0478', 'W0733', 'W0945', 'W0951', 'W1009', 'W1100', 'W1263', 'W1330', 'W1336', 'W1337', 'W1393', 'W1514', 'W1518']
# senescence ['W0058', 'W1393']
# cardiovascular disease ['W0058', 'W0312', 'W0719', 'W1318', 'W1329', 'W1393', 'W1433', 'W1443']
# b cells ['W0058', 'W1393']
# cerebrospinal fluid ['W0058', 'W1495']
# autoreactive ['W0058', 'W1325']
# peritoneal cavity ['W0058', 'W1393']
# b cell repertoire ['W0058', 'W1393']
# transcription factors ['W0058', 'W1393']
# proteomics ['W0058', 'W0176', 'W0249', 'W1342']
# rodent ['W0058', 'W1337', 'W1393']
# neutrophils ['W0058', 'W1342', 'W1393', 'W1394', 'W1518']
# saliva ['W0058', 'W0437']
# b cells immunoglobulins ['W0058', 'W1393']
# proinflammatory th17 cells ['W0058', 'W1393']
# bone marrow ['W0058', 'W1393', 'W1509']
# gene regulation ['W0058', 'W0082', 'W0176', 'W1326', 'W1342']
# alzheimer’s disease ['W0058', 'W0134']
# phagocytosis ['W0058', 'W1393', 'W1394', 'W1409']
# antibody ['W0058', 'W1393']
# systemic ['W0058', 'W1393']
# cd25 ['W0058', 'W1393']
# antigen presentation ['W0058', 'W1393']
# psoralen ['W0058', 'W0073']
# cell biology ['W0058', 'W0063', 'W0070', 'W1327', 'W1340', 'W1341', 'W1393']
# influenza ['W0058', 'W1326', 'W1393', 'W1429']
# mouse model ['W0058', 'W1393']
# cell death ['W0058', 'W0063', 'W1337', 'W1514']
# repertoire development ['W0058', 'W1393']
# b-1 cell subset ['W0058', 'W1393']
# b-1 cells ['W0058', 'W1393']
# atherosclerosis ['W0058', 'W0176', 'W0453', 'W1325', 'W1329', 'W1393', 'W1420']
# b1 cells ['W0058', 'W1393']
# igm antibodies ['W0058', 'W1393']
# methamphetamine ['W0059', 'W1013', 'W1446', 'W1505', 'W1507']
# paraphilia ['W0059', 'W0448', 'W1446', 'W1460']
# opioid ['W0059', 'W1013', 'W1278', 'W1336', 'W1376', 'W1446']
# loperamide ['W0059', 'W1446']
# inflammatory bowel disease ['W0059', 'W1411', 'W1428', 'W1446', 'W1455']
# autopsy ['W0059', 'W1440', 'W1441', 'W1443', 'W1444', 'W1446']
# toxicology ['W0059', 'W0435', 'W0437', 'W1356', 'W1446']
# drug delivery route ['W0059', 'W1446']
# pica ['W0059', 'W0911', 'W1021']
# cocaine ['W0059', 'W0342', 'W0343', 'W0349', 'W0437', 'W1008', 'W1010', 'W1013', 'W1024', 'W1336', 'W1343', 'W1442', 'W1446']
# benzoylecgonine ['W0059', 'W1442', 'W1446']
# maternal zygotic transition ['W0072', 'W0084']
# spinal cord ['W0072', 'W0081', 'W1330', 'W1341', 'W1427']
# lens ['W0072', 'W0084']
# e-cadherin ['W0072', 'W0084', 'W1342']
# xanthophore ['W0072', 'W0084']
# iridophore ['W0072', 'W0084']
# n-cadherin ['W0072', 'W0084']
# kugelig ['W0072', 'W0084']
# body shape ['W0072', 'W0084', 'W0086', 'W1318']
# mesoderm patterning ['W0072', 'W0084']
# endothelium ['W0072', 'W0084', 'W0176', 'W1342']
# kidney ['W0072', 'W1325', 'W1341', 'W1460']
# mutant ['W0072', 'W1328']
# cytokinesis ['W0072', 'W0084']
# eye ['W0072', 'W0084']
# epiboly ['W0072', 'W0084']
# forebrain ['W0072', 'W0084']
# neurulation ['W0072', 'W0084']
# dino ['W0072', 'W0084']
# otic placode ['W0072', 'W0084']
# nodal ['W0072', 'W0084']
# skin ['W0072', 'W0084', 'W0342', 'W1483', 'W1496']
# regionalization ['W0072', 'W0084']
# half baked ['W0072', 'W0084']
# survival ['W0072', 'W0084', 'W1514']
# neurogenic genes ['W0072', 'W0084']
# spadetail ['W0072', 'W0084']
# intermediate mesoderm ['W0072', 'W0084']
# notochord ['W0072', 'W0084']
# tbx16 ['W0072', 'W0084']
# heart ['W0072', 'W0342', 'W0343', 'W0349', 'W1325']
# antisense ['W0072', 'W0084']
# one-eyed pinhead ['W0072', 'W0084']
# muscle pioneer cells ['W0072', 'W0084']
# endoreduplication ['W0072', 'W0084']
# dominant ['W0072', 'W0084']
# gain-of-function ['W0072', 'W0084']
# convergence ['W0072', 'W0076', 'W0084', 'W0086', 'W0221', 'W0222']
# dorsoventral axis ['W0072', 'W0084']
# embryonic fin fold ['W0072', 'W0084']
# brain ventricles ['W0072', 'W0084']
# axis extension ['W0072', 'W0084']
# involution ['W0072', 'W0084', 'W0841']
# pronephros ['W0072', 'W0084']
# no tail ['W0072', 'W0084']
# mitosis promoting factor ['W0072', 'W0084']
# doc ['W0072', 'W0084']
# dorsalization ['W0072', 'W0084']
# left–right asymmetry ['W0072', 'W0084']
# cell adhesion ['W0072', 'W0084', 'W1518']
# one-eyed-pinhead ['W0072', 'W0084']
# stemcell ['W0072', 'W0084']
# g2/m transition ['W0072', 'W0084']
# zygotic-maternal effect ['W0072', 'W0084']
# neural induction ['W0072', 'W0084']
# dorsal forerunner cell ['W0072', 'W0084']
# affinity ['W0072', 'W0084']
# sonic hedgehog ['W0072', 'W0084']
# axial development ['W0072', 'W0084']
# hearing ['W0072', 'W1175', 'W1178']
# blastula ['W0072', 'W0084']
# balance ['W0072', 'W0244', 'W0665', 'W0668', 'W0951', 'W1175', 'W1263']
# trilobite ['W0072', 'W0084']
# nodal signals ['W0072', 'W0084']
# cyclin b ['W0072', 'W0084']
# racgap1 ['W0072', 'W0084']
# heterophilic ['W0072', 'W0084']
# hypoblast ['W0072', 'W0084']
# neurocranium ['W0072', 'W0084']
# regionalisation ['W0072', 'W0084']
# otolith ['W0072', 'W1175']
# neuronal development ['W0072', 'W0081', 'W0084']
# homodimer ['W0072', 'W0084']
# wilson cell ['W0072', 'W0084']
# specification ['W0072', 'W0084']
# heterodimer ['W0072', 'W0084']
# enveloping layer ['W0072', 'W0084']
# retina ['W0072', 'W0076', 'W0085', 'W0909']
# motoneurons ['W0072', 'W0084', 'W1341']
# neural crest ['W0072', 'W0084']
# pectoral fins ['W0072', 'W0084']
# ectoderm ['W0072', 'W0084']
# cadherin ['W0072', 'W0084']
# pharyngeal arch ['W0072', 'W0084']
# extension ['W0072', 'W0084']
# blastoderm ['W0072', 'W0084']
# yolk syncytial layer ['W0072', 'W0084']
# blood ['W0072', 'W0084', 'W1325']
# inner ear ['W0072', 'W1328']
# radial intercalation ['W0072', 'W0084']
# adult fins ['W0072', 'W0084']
# melanophore ['W0072', 'W0084']
# floating head ['W0072', 'W0084']
# mitosis ['W0072', 'W0084', 'W1342']
# muscle pioneers ['W0072', 'W0084']
# pipetail ['W0072', 'W0084']
# nutrient ['W0073', 'W0420']
# performance ['W0073', 'W0208', 'W0244', 'W0245', 'W0255', 'W0352', 'W0698', 'W0788', 'W0790', 'W0791', 'W0798', 'W0826', 'W0945', 'W1138', 'W1212']
# phenolics ['W0073', 'W0187']
# growth ['W0073', 'W0315', 'W0334', 'W0474', 'W1178', 'W1326', 'W1337']
# protein ['W0073', 'W0201', 'W1460', 'W1514']
# herbivory ['W0073', 'W0086']
# plant defense ['W0073', 'W0078']
# nutrients ['W0073', 'W0453']
# systems biology ['W0074', 'W0078']
# tuberculosis ['W0074', 'W1024', 'W1413', 'W1482', 'W1514']
# biofilm ['W0074', 'W1514', 'W1520']
# host-pathogen interactions ['W0074', 'W0088']
# carbonate ['W0074', 'W0560']
# metabolism ['W0074', 'W0660', 'W0841', 'W1326', 'W1329', 'W1433', 'W1460', 'W1514']
# bile ['W0074', 'W1507']
# virulence ['W0074', 'W0079', 'W1344']
# invasion ['W0074', 'W1326']
# glutamate ['W0076', 'W1013', 'W1336', 'W1495']
# pig ['W0076', 'W1329', 'W1433']
# retinal ganglion cells ['W0076', 'W0085']
# brdu ['W0076', 'W0085']
# retinal ganglion cell ['W0076', 'W0085']
# müller glia ['W0076', 'W0085']
# glaucoma ['W0076', 'W0085']
# lateral inhibition ['W0076', 'W1337']
# long evans rats ['W0076', 'W0085']
# calcium ['W0076', 'W0184']
# neuroprotection ['W0076', 'W0085']
# glaucoma treatment ['W0076', 'W0085']
# alpha7 nachrs ['W0076', 'W0085']
# neural network ['W0076', 'W0245', 'W0341', 'W0351', 'W0362', 'W0411', 'W1354']
# neuropharmacology ['W0076', 'W0085', 'W1336', 'W1337', 'W1343']
# cholinergic neuroprotection ['W0076', 'W0085']
# gene therapy ['W0076', 'W0085', 'W1404', 'W1518']
# rat ['W0076', 'W0474', 'W1008', 'W1010', 'W1024', 'W1326', 'W1329', 'W1336', 'W1337']
# medicine ['W0076', 'W0393']
# neurophysiology ['W0076', 'W0077']
# in vivo ['W0076', 'W1336']
# crayfish ['W0076', 'W0411']
# scholarship of teaching and learning ['W0137', 'W0326', 'W0944', 'W1267', 'W1330', 'W1340']
# instructional design ['W0137', 'W0324', 'W0790', 'W0796', 'W1321']
# infant ['W0137', 'W1176', 'W1446']
# health promotion ['W0138', 'W0139', 'W0747', 'W0901', 'W1040', 'W1429']
# prevention ['W0138', 'W0242', 'W0244', 'W0264', 'W0303', 'W0667', 'W0901', 'W0945', 'W1012', 'W1015', 'W1121', 'W1390', 'W1429', 'W1460', 'W1495', 'W1514', 'W1520']
# self-management ['W0139', 'W0155', 'W0164', 'W1020', 'W1021', 'W1024']
# quality of life ['W0139', 'W0437', 'W1182', 'W1406', 'W1408', 'W1433', 'W1460', 'W1509', 'W1511']
# adolescence ['W0139', 'W0547', 'W0660', 'W0904', 'W1016', 'W1019', 'W1063', 'W1108', 'W1122', 'W1219', 'W1369', 'W1429', 'W1433', 'W1438', 'W1449', 'W1460', 'W1463']
# ...
# advanced cardiac life support ['W1392', 'W1483']
# klebsiella ['W1394', 'W1514']
# academic advising ['W1395', 'W1398']
# health inequities ['W1397', 'W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# resident education ['W1397', 'W1485', 'W1501', 'W1511', 'W1512', 'W1514']
# residency training ['W1400', 'W1479', 'W1482']
# psychiatric disorders ['W1401', 'W1495']
# internal medicine ['W1401', 'W1403', 'W1410', 'W1411', 'W1412', 'W1414', 'W1417', 'W1418', 'W1421', 'W1423', 'W1424', 'W1425', 'W1482']
# medical law ['W1401', 'W1482']
# paediatrics ['W1401', 'W1463', 'W1482']
# clinical ethics ['W1401', 'W1405']
# clinical ethicist ['W1401', 'W1405']
# ultrasonography ['W1401', 'W1482']
# transgender ['W1401', 'W1448', 'W1460', 'W1479']
# counter-transference ['W1401', 'W1405']
# diagnostic overshadowing ['W1401', 'W1448', 'W1479']
# clinical ethics consultation ['W1401', 'W1405']
# intensive &amp; critical care ['W1401', 'W1482']
# medical student education ['W1404', 'W1479']
# nusinersen ['W1404', 'W1471']
# cognitive function ['W1404', 'W1448']
# smn ['W1404', 'W1471']
# adaptive function ['W1404', 'W1448']
# iems or metabolic disorders ['W1404', 'W1473']
# cholesterol biosynthesis ['W1404', 'W1479']
# developmental-behavioral pediatrics ['W1404', 'W1479']
# psychological assessment ['W1404', 'W1473']
# onasemnogene abeparvovec ['W1404', 'W1471']
# neurodevelopmental disorders (ndd) ['W1404', 'W1473']
# sterol metabolism disorders ['W1404', 'W1479']
# biopsychosocial lens ['W1404', 'W1473']
# risdiplam ['W1404', 'W1471']
# intellectual developmental disorder ['W1404', 'W1448']
# behavioral disorders ['W1404', 'W1473']
# general adult psychiatry ['W1405', 'W1491', 'W1493']
# learning environment ['W1406', 'W1408']
# sport-related concussion ['W1406', 'W1408']
# librarians ['W1406', 'W1407']
# evidence based medicine ['W1407', 'W1460']
# antibiotic use ['W1409', 'W1418']
# portal vein thrombosis ['W1411', 'W1414']
# crohn’s disease ['W1411', 'W1428', 'W1455']
# coronary artery disease ['W1411', 'W1420']
# endocarditis ['W1413', 'W1428', 'W1482']
# cardiovascular medicine ['W1413', 'W1482']
# infections ['W1413', 'W1514']
# infectious diseases ['W1413', 'W1427', 'W1429', 'W1514']
# antimicrobial stewardship ['W1413', 'W1514']
# peritonitis ['W1413', 'W1446', 'W1482', 'W1514']
# tropical medicine ['W1413', 'W1428']
# eastern equine encephalitis ['W1414', 'W1415', 'W1443']
# hepatic abscess ['W1414', 'W1514']
# arbovirus ['W1414', 'W1415', 'W1443']
# viral encephalitis ['W1414', 'W1415', 'W1443']
# bacteremia ['W1416', 'W1482']
# pyomyositis ['W1416', 'W1482']
# temperate ['W1416', 'W1482']
# staphylococcus aureus ['W1416', 'W1482', 'W1514']
# coronary artery ['W1420', 'W1446']
# coronary artery bypass grafting ['W1420', 'W1514']
# mortality ['W1420', 'W1442', 'W1446', 'W1454', 'W1508', 'W1509', 'W1514']
# matrix metalloproteinase ['W1420', 'W1429']
# coronary arteries ['W1420', 'W1446']
# bleeding ['W1420', 'W1456']
# drug therapy ['W1420', 'W1495']
# clinical clerkship ['W1421', 'W1461']
# parasite ['W1425', 'W1446']
# neurotoxicity ['W1425', 'W1460']
# meningitis ['W1427', 'W1428']
# systems-based practice ['W1427', 'W1432']
# practice-based learning and improvement ['W1427', 'W1432']
# renal cell carcinoma ['W1427', 'W1446']
# history of medicine ['W1427', 'W1448', 'W1460', 'W1512', 'W1514']
# malnutrition ['W1428', 'W1455', 'W1514']
# cardio-oncology ['W1428', 'W1482']
# exclusive enteral nutrition ['W1428', 'W1455']
# cysticercosis ['W1428', 'W1446']
# cardiac neoplasms ['W1428', 'W1482']
# venous thromboembolism ['W1428', 'W1514']
# cerebral palsy ['W1428', 'W1446', 'W1455', 'W1460', 'W1463']
# sars-cov-2 ['W1429', 'W1510', 'W1512', 'W1514']
# chlamydia trachomatis ['W1429', 'W1460']
# vaccination ['W1429', 'W1514']
# family planning ['W1429', 'W1435']
# sexual activity ['W1429', 'W1460']
# recommendations ['W1429', 'W1514']
# immunization ['W1429', 'W1460', 'W1514']
# infection ['W1429', 'W1514', 'W1520']
# vaccines ['W1429', 'W1460']
# prolactin ['W1430', 'W1433', 'W1460']
# testosterone ['W1430', 'W1433']
# maternal-fetal medicine ['W1430', 'W1432']
# laparoscopy ['W1432', 'W1485']
# type 2 diabetes ['W1433', 'W1505']
# hyperprolactinemia ['W1433', 'W1495']
# nomenclature ['W1433', 'W1495']
# menorrhagia ['W1433', 'W1460']
# estrogens ['W1433', 'W1514']
# epilepsy ['W1433', 'W1446', 'W1451', 'W1460']
# adrenal insufficiency ['W1433', 'W1514']
# lithium ['W1433', 'W1495']
# congenital adrenal hyperplasia ['W1433', 'W1454']
# estrogen ['W1433', 'W1491']
# arteriovenous malformation ['W1433', 'W1446']
# multiple gestations ['W1433', 'W1512']
# gynecology ['W1436', 'W1460']
# fibrosis ['W1439', 'W1519', 'W1520']
# musculoskeletal ['W1439', 'W1519', 'W1520']
# pediatric orthopaedics ['W1439', 'W1519']
# orthopaedic surgery ['W1439', 'W1519']
# tgf-ß ['W1439', 'W1519', 'W1520']
# congenital ['W1439', 'W1463']
# supracondylar humerus fracture ['W1439', 'W1519']
# extracellular matrix ['W1439', 'W1519', 'W1520']
# general orthopaedics ['W1439', 'W1519']
# superficial tangential gunshot wound ['W1440', 'W1446']
# gunshot wound ['W1440', 'W1446']
# railroad ['W1440', 'W1446']
# ballistics ['W1440', 'W1446']
# train ['W1440', 'W1446']
# bullet track skin defect ['W1440', 'W1446']
# bone histology ['W1441', 'W1443', 'W1446']
# skeletal trauma ['W1441', 'W1446']
# fingerprints ['W1441', 'W1446']
# preservation ['W1441', 'W1443', 'W1446']
# time since fracture ['W1441', 'W1446']
# posttraumatic survival time ['W1441', 'W1446']
# decalcification ['W1441', 'W1443', 'W1446']
# cranial fracture ['W1441', 'W1446']
# fracture healing ['W1441', 'W1446']
# bone regeneration ['W1441', 'W1518']
# hydrochloric acid ['W1441', 'W1443', 'W1446']
# il ['W1442', 'W1514']
# asphyxia ['W1442', 'W1446']
# carbon monoxide ['W1442', 'W1443', 'W1446']
# pathology and biology ['W1442', 'W1446']
# intracranial hemorrhage ['W1442', 'W1446']
# hyperthermia ['W1442', 'W1443']
# electrocution ['W1442', 'W1446']
# carboxyhemoglobin ['W1442', 'W1446']
# driving ['W1443', 'W1497']
# burns ['W1443', 'W1446', 'W1505', 'W1507']
# autosomal dominant ['W1443', 'W1446']
# sudden cardiac death ['W1443', 'W1446', 'W1451', 'W1460']
# luxol fast blue stain ['W1443', 'W1446']
# meningioma ['W1443', 'W1446']
# hydrocephalus ['W1443', 'W1446']
# central pontine myelinolysis ['W1443', 'W1446']
# hyponatremia ['W1443', 'W1446', 'W1497']
# case series ['W1443', 'W1446']
# forensic autopsy ['W1443', 'W1444', 'W1446']
# who grade ['W1443', 'W1446']
# accident ['W1443', 'W1446']
# sudden death ['W1444', 'W1446']
# surgery ['W1446', 'W1505', 'W1509', 'W1510', 'W1511', 'W1512', 'W1514']
# newborn ['W1446', 'W1460', 'W1463', 'W1479']
# pulmonary hypoplasia ['W1446', 'W1485']
# pathology ['W1446', 'W1495']
# neuroblastoma ['W1446', 'W1483']
# gastrointestinal ['W1446', 'W1456', 'W1511', 'W1512']
# dermatology ['W1446', 'W1460', 'W1496', 'W1509']
# congenital diaphragmatic hernia ['W1446', 'W1485']
# hepatobiliary ['W1446', 'W1511', 'W1512']
# abdominal ['W1446', 'W1514']
# hypothermia ['W1446', 'W1514']
# pulmonary ['W1446', 'W1460']
# psychiatric ['W1446', 'W1495']
# deliberate self-harm ['W1448', 'W1460']
# housing instability ['W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# etiology ['W1448', 'W1460', 'W1463', 'W1479', 'W1495']
# firearms and suicide ['W1448', 'W1460', 'W1469']
# suicide in adolescents ['W1448', 'W1460', 'W1469']
# integrated care ['W1448', 'W1460']
# medical training curricula ['W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# lgbt persons ['W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# cystic fibrosis ['W1448', 'W1459', 'W1463']
# neurobiology of suicide and depression ['W1448', 'W1460', 'W1469']
# suicide risk ['W1448', 'W1460']
# assessment of suicidality ['W1448', 'W1460', 'W1469']
# climate control ['W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# rural communities ['W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# brain stimulation procedures ['W1448', 'W1460', 'W1469']
# peer health navigators ['W1448', 'W1451', 'W1452', 'W1454', 'W1460']
# suicide in the pediatric athlete ['W1448', 'W1460', 'W1469']
# multidisciplinary ['W1448', 'W1452', 'W1473']
# suicide in children ['W1448', 'W1460', 'W1469']
# suicide pharmacology ['W1448', 'W1460', 'W1469']
# symptoms ['W1448', 'W1495']
# body dissatisfaction ['W1448', 'W1460']
# mental pain ['W1449', 'W1460']
# attention-deficit/hyperactivity disorder (adhd) ['W1449', 'W1472', 'W1479']
# pharmacy ['W1449', 'W1460']
# bipolar switching ['W1449', 'W1460']
# anxiety disorders ['W1449', 'W1460', 'W1486']
# serotonin syndrome ['W1449', 'W1460']
# selective-serotonin reuptake inhibitors ['W1449', 'W1460']
# sports-related concussion ['W1451', 'W1460']
# overuse injuries ['W1451', 'W1460']
# genitourinary disorders ['W1451', 'W1460']
# sports anemia ['W1451', 'W1460']
# dermatology disorders in sports ['W1451', 'W1460']
# sports nutrition ['W1451', 'W1460']
# newborn care ['W1451', 'W1472', 'W1474']
# iron deficiency anemia ['W1451', 'W1460']
# hospital medicine ['W1451', 'W1455']
# female athlete triad ['W1451', 'W1460']
# sports readiness ['W1451', 'W1460', 'W1479']
# mental health care ['W1451', 'W1479']
# gastrointestinal disorders ['W1451', 'W1460']
# mepolizumab ['W1452', 'W1460', 'W1463']
# acne conglobata ['W1452', 'W1460']
# acne vulgaris ['W1452', 'W1460']
# environmental triggers ['W1452', 'W1460', 'W1463']
# mental health of athletes ['W1452', 'W1454', 'W1460']
# sapho syndrome ['W1452', 'W1460']
# acne excoriée ['W1452', 'W1460']
# atlantoaxial instability ['W1452', 'W1454', 'W1460']
# blood doping ['W1452', 'W1454', 'W1460']
# pediatric sports medicine ['W1452', 'W1454', 'W1460', 'W1467']
# emotional sequelae ['W1452', 'W1460']
# sports attrition ['W1452', 'W1454', 'W1460']
# isotretinoin ['W1452', 'W1460']
# reaction to injuries ['W1452', 'W1454', 'W1460']
# endotypes ['W1452', 'W1460', 'W1463', 'W1468']
# leukotriene modulators/montelukast ['W1452', 'W1460', 'W1463']
# short-acting beta-2 agonists (saba) ['W1452', 'W1460', 'W1463']
# sleep disturbances ['W1452', 'W1460', 'W1463']
# acne neonatorum ['W1452', 'W1460']
# behavioral aspects ['W1452', 'W1454', 'W1460']
# autonomic dysreflexia ['W1452', 'W1454', 'W1460']
# acne ['W1452', 'W1460']
# inhaled corticosteroids ['W1452', 'W1460', 'W1463']
# ergolytic drugs ['W1452', 'W1454', 'W1460']
# antibiotic resistance ['W1452', 'W1460', 'W1514', 'W1520']
# hidradenitis suppurativa ['W1452', 'W1460']
# topical retinoids ['W1452', 'W1460']
# omalizumab ['W1452', 'W1460', 'W1463']
# sports doping ['W1452', 'W1454', 'W1460']
# gene doping ['W1452', 'W1454', 'W1460']
# acne rosacea ['W1452', 'W1460']
# wheelchair athletes ['W1452', 'W1454', 'W1460']
# acne fulminans ['W1452', 'W1460']
# acneiform disorders ['W1452', 'W1460']
# amputee athletes ['W1452', 'W1454', 'W1460']
# disabled athletes ['W1452', 'W1454', 'W1460']
# hyperglycemia ['W1453', 'W1505']
# mody ['W1453', 'W1460']
# diabetes in youth ['W1453', 'W1460']
# autoimmunity in diabetes ['W1453', 'W1460']
# adult height ['W1454', 'W1460', 'W1475']
# ovarian mass ['W1454', 'W1460']
# gnrh agonists ['W1454', 'W1460', 'W1475']
# pediatric obesity ['W1454', 'W1475']
# ovarian tumor ['W1454', 'W1460']
# adnexal mass ['W1454', 'W1460']
# central precocious puberty (cpp) ['W1454', 'W1460', 'W1475']
# germ-cell tumor ['W1454', 'W1460']
# menarche ['W1454', 'W1460', 'W1475']
# congenital portosystemic shunt ['W1455', 'W1480']
# hyperammonemia ['W1455', 'W1480']
# insomnia ['W1458', 'W1460', 'W1463']
# obstructive sleep apnea ['W1458', 'W1460', 'W1463']
# antidepressants ['W1460', 'W1495']
# melatonin ['W1460', 'W1463']
# adverse effects ['W1460', 'W1495']
# atypical antipsychotics ['W1460', 'W1495']
# causes ['W1460', 'W1495']
# abdominal pain ['W1460', 'W1514']
# bariatric surgery ['W1460', 'W1479', 'W1505', 'W1512', 'W1514']
# antipsychotics ['W1460', 'W1495']
# psychopharmacology ['W1460', 'W1495']
# mood stabilizers ['W1460', 'W1495']
# overweight ['W1460', 'W1479', 'W1512']
# rct ['W1460', 'W1495']
# apnea ['W1463', 'W1505']
# pediatric sleep medicine ['W1463', 'W1471']
# sleep medicine ['W1463', 'W1471']
# general pediatrics ['W1466', 'W1467', 'W1474']
# pediatric endocrinology and metabolism ['W1466', 'W1470']
# integrative medicine ['W1472', 'W1479', 'W1497']
# child psychology ['W1476', 'W1490']
# medical comorbidity ['W1479', 'W1514']
# antipsychotic agents ['W1479', 'W1495']
# clinical features ['W1479', 'W1495']
# sleep studies ['W1482', 'W1495']
# polysomnography ['W1482', 'W1495']
# sleep apnea ['W1482', 'W1495']
# pediatric surgery ['W1484', 'W1485']
# appendicitis ['W1485', 'W1510', 'W1512', 'W1514']
# score® curriculum ['W1485', 'W1511', 'W1512', 'W1514']
# absite ['W1485', 'W1511', 'W1512', 'W1514']
# abscess ['W1485', 'W1509']
# medical knowledge ['W1485', 'W1511', 'W1512', 'W1514']
# electroconvulsive therapy ['W1491', 'W1495']
# psychosomatic medicine ['W1491', 'W1496']
# duration ['W1495', 'W1514']
# weight gain ['W1497', 'W1514']
# virtual exams ['W1504', 'W1511', 'W1512', 'W1514']
# spinal anesthesia ['W1504', 'W1512']
# american board of surgery certifying examination ['W1504', 'W1511', 'W1512', 'W1514']
# operative autonomy ['W1504', 'W1510', 'W1511', 'W1512', 'W1514']
# zwisch scale ['W1504', 'W1510', 'W1511', 'W1512', 'W1514']
# recurrent groin hernias ['W1504', 'W1512']
# post-operative outcomes ['W1504', 'W1505', 'W1511', 'W1512', 'W1514']
# inguinal hernia ['W1504', 'W1511', 'W1512', 'W1514']
# oral examination ['W1504', 'W1510', 'W1511', 'W1512', 'W1514']
# local anesthesia ['W1504', 'W1512']
# mock orals ['W1504', 'W1511', 'W1512', 'W1514']
# strangulated femoral hernia ['W1504', 'W1511', 'W1512', 'W1514']
# intraoperative evaluation ['W1504', 'W1510', 'W1511', 'W1512', 'W1514']
# femoral hernia ['W1504', 'W1511', 'W1512', 'W1514']
# roux-en-y gastric bypass ['W1505', 'W1514']
# usmle step 1 ['W1505', 'W1510', 'W1511', 'W1512', 'W1514']
# step 2 c k ['W1505', 'W1510', 'W1511', 'W1512', 'W1514']
# adjustable gastric banding ['W1505', 'W1514']
# surgical education ['W1505', 'W1511', 'W1512', 'W1514', 'W1519']
# postoperative ['W1505', 'W1512']
# surgical site infection ['W1505', 'W1511', 'W1512', 'W1514']
# resident preparedness ['W1505', 'W1511', 'W1512', 'W1514']
# gastric bypass ['W1505', 'W1514']
# resident performance evaluation ['W1505', 'W1511', 'W1512', 'W1514']
# resident autonomy ['W1505', 'W1511', 'W1512', 'W1514']
# surgical training ['W1505', 'W1510', 'W1511', 'W1512', 'W1514']
# readiness for independent practice ['W1505', 'W1511', 'W1512', 'W1514']
# residents' assessment ['W1505', 'W1511', 'W1512', 'W1514']
# electronic residency application service® (eras®) ['W1505', 'W1510', 'W1511', 'W1512', 'W1514']
# pseudoephedrine ['W1505', 'W1507']
# bariatric ['W1505', 'W1512']
# trauma acute care ['W1508', 'W1512', 'W1514']
# acute care surgery ['W1508', 'W1512', 'W1514']
# portal hypertension ['W1509', 'W1510']
# reoperation ['W1509', 'W1514']
# scholarly activity ['W1510', 'W1512', 'W1514']
# general surgery clerkship ['W1510', 'W1512']
# hemorrhagic shock ['W1510', 'W1513']
# eras   application  ® ['W1510', 'W1511', 'W1512']
# residents ranking ['W1510', 'W1511', 'W1512']
# surgery residency ['W1510', 'W1512', 'W1514']
# eras ['W1510', 'W1511', 'W1512', 'W1514']
# medical student perception ['W1510', 'W1512']
# wses ['W1510', 'W1512', 'W1514']
# cholecystitis ['W1510', 'W1512', 'W1514']
# emergency surgery ['W1510', 'W1512', 'W1514']
# surgery residency application ['W1510', 'W1511', 'W1512']
# pancreaticoduodenectomy ['W1511', 'W1512', 'W1514']
# elderly patient ['W1511', 'W1512']
# general surgery education ['W1511', 'W1512', 'W1514']
# distal pancreatectomy ['W1511', 'W1512']
# whipple ['W1511', 'W1512']
# gender disparity ['W1511', 'W1512', 'W1514']
# hpb resident education ['W1511', 'W1512']
# complex surgery in the community ['W1511', 'W1512']
# self-assessment ['W1511', 'W1512', 'W1514']
# community hospital ['W1511', 'W1512']
# surgical quality ['W1511', 'W1512', 'W1514']
# hpb surgery outcomes ['W1511', 'W1512']
# age-related outcomes ['W1511', 'W1512']
# pancreatectomy ['W1511', 'W1512']
# acgme core competency ['W1511', 'W1512', 'W1514']
# stryker ['W1512', 'W1514']
# virtual interviews ['W1512', 'W1514']
# surgery history ['W1512', 'W1514']
# surgical training in kalamazoo ['W1512', 'W1514']
# residency applications ['W1512', 'W1514']
# adult critical care ['W1513', 'W1514']
# bacteriophage ['W1514', 'W1520']
# blood clots ['W1514', 'W1520']
# tissue repair ['W1514', 'W1520']
# compounds ['W1514', 'W1520']
# tgf-β1 ['W1518', 'W1520']
# muscle injuries ['W1519', 'W1520']
# biologic healing enhancement ['W1519', 'W1520']
# platelet-rich plasma ['W1519', 'W1520']

# %% [markdown]
# Creating a new dictionary that adds researcher names and affiliations to each of the researcherIDs. Exporting final file that lists each faculty and their departmental affiliations for each keyword.

# %%
#creating researcherID:researcherName,researcherAffiliation dictionary outside of loop
uniqueIDaffil_dict = dict({})

#looping through each entry within the researcherID:researcherName,researcherAffiliation dictionary
with open(researcher_affiliation, 'r', encoding="utf8") as f: #opening file
    uniqueID_name_affiliation = f.readlines() #reading in file as string
    for line in uniqueID_name_affiliation: #for each researcherID, researcherName, researchAffiliation within line
        temp_list = line.rstrip('\n').replace(';',':').split(':') #split line of string into list
        uniqueID = temp_list[0] #take the first value in list (researcherID) and put it into a temporary list
        name = temp_list[1] #take the second value in list (researcherName) and put in temporary list
        affiliation = temp_list[2] #take the third value in list (researcherAffiliation) and put in temporary list
        uniqueIDaffil_dict[uniqueID] = (name,affiliation) #create dictionary entry, setting key as researcherID and values as researcherName and researcherAffiliation

#creating keyword:researcherID,researcherName,researcherAffiliation dictionary outside of loop
keyresearaffil_dict = dict({})

#looping through each entry within the researcherID:keyword dictionary
for keyword, uniqueIDs in keyresear_dict.items():
    affiliations = [] #affiliations placeholder list
    userIDs = [] #researcherIDs placeholder list
    userNames = [] #researcherNames placeholder list
    
    #looping through each researcherID value within researcherID:keyword dictionary
    for uniqueID in uniqueIDs:
        affiliations.append(uniqueIDaffil_dict[uniqueID][1]) #add associated affiliation from within the researcherID:researcherName,researcherAffiliation dictionary to affiliations placeholder list
        userIDs.append(uniqueID) #add associated researcherID to researcherIDs placeholder list
        userNames.append(uniqueIDaffil_dict[uniqueID][0]) #add associated researcherNames from within the researcherID:researcherName,researcherAffiliation dictionary to researcherNames placeholder list
    keyresearaffil_dict[keyword] = [userIDs,userNames,list(set(affiliations))] #setting dictionary key:values, deduplicating affiliations

#creating dataframe from dictionary, where the keyword is one column, researcherIDs are second column, researcherNames are third column, and researcherAffiliations are fourth column  
keyresearaffil_dataframe = pd.DataFrame.from_dict(keyresearaffil_dict, orient='index')

#looking up today's date and exporting dataframe to comma separated value file with utf-8 encoding  
todays_date = date.today()
keyresearaffil_dataframe.to_csv(f"{todays_date.isoformat()}_WMUresearcher_keywords_affiliation.csv", index=True, encoding='utf-8-sig')
